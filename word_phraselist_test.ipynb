# %%
#Imports
import sys
import datetime
import re
from datetime import timedelta

sys.path.append('../../')

from pyspark.sql import SparkSession, Row
from pyspark.ml import Pipeline

# from sparknlp.annotator import *
# from sparknlp.common import RegexRule
# from sparknlp.base import DocumentAssembler, Finisher
from pyspark.sql.functions import explode

from dateutil.parser import parse
# for tokenizing
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk import pos_tag, RegexpParser

# for schema
from pyspark.sql.types import *

# for testing 
import random

# %%
# instantiate a spark context object
appname= "word-phrase-list"
master="local"

# Create Spark Session
spark = SparkSession.builder.appName(appname)\
                .config("spark.cassandra.connection.host", "localhost")\
                .config("spark.cassandra.connection.port", "9042")\
                .config("spark.eventLog.enabled", True)\
                .config("spark.eventLog.dir", "/home/ubuntu/spark_tmp/")\
                .getOrCreate()

# %%
trump_json = 's3a://twitter-data-dump/celebrities/trump.json'

trump_df = spark.read.json(trump_json)

resource_path ='/home/ubuntu/Desktop/spark-nlp/src/test/resources/'
#type(data) --> data frame

# %%
trump_df.printSchema()
trump_df.take(10)[5]
# Out:
# root
#  |-- created_at: string (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- id_str: string (nullable = true)
#  |-- is_retweet: boolean (nullable = true)
#  |-- retweet_count: long (nullable = true)
#  |-- source: string (nullable = true)
#  |-- text: string (nullable = true)
# Row(created_at=u'Tue Jan 23 04:30:33 +0000 2018', favorite_count=103887, id_str=u'955658992793149440', is_retweet=False, retweet_count=23224, source=u'Twitter for iPhone', text=u'Big win for Republicans as Democrats cave on Shutdown. Now I want a big win for everyone, including Republicans, Democrats and DACA, but especially for our Great Military and Border Security. Should be able to get there. See you at the negotiating table!')

# %%
# trump data frame to base_df
# note i split the data into 666 and 1666 id set
def trump_mapper(row):
    # set default trump as 666
    uid = 666    
    tid = row[2]
    creation_time = row[0]
    retweet_count = row[4]    
    favorite_count = row[1]
    tweet = row[-1]
    if len(tweet) > 200:
        uid = 1666
    
    time_zone = 'blabla'
    followers_count='100'
    friends_count= '2000'
    city_name='Washington'
    country_name = 'U.S'
    media_ary = []
    hashtag_ary = []
    return (tid, uid, tweet, creation_time,
            time_zone, followers_count,
            friends_count, city_name, country_name,
            media_ary, hashtag_ary, retweet_count,
            favorite_count )
        
#trump_rdd = trump_df.rdd.map(trump_mapper)

# %%
# Modfication for single word extraction as well
# Modfication for single word extraction as well
# Modfication for single word extraction as well

# extract word_list(exclusing noun+stopwords) and noun phrase list
def extract_entity(tokens):
    tokens_tag = pos_tag(tokens)
    # in case tokens_tags are emtpy, return empty list
    if (len(tokens_tag) == 0):
        return []
            
    # set up for entity extraction 
    grammar = "NP: {<DT>?<JJ.*>*<NN.*>+}"
    cp = RegexpParser(grammar)
    np_ary = []

    root_tree = cp.parse(tokens_tag)
    for i in list( root_tree.subtrees(filter=lambda x: x.label() == 'NP')):
        st = ""
        for t in i.leaves():
            st = st + t[0] + " "
        np_ary.append(st.strip())
    # entity extracted   
    
    # combine them together
    #    np_ary = np_ary + word_list
    return np_ary
    
# return 2 items: sentence_count,  <word_tuple>, <name_entity>
def process_tweet(description):
    # base case
    if description is None or description == "":
        return (0,[],[])
    # filter out http items
    description =\
        re.sub(r'https:[^\s]*', '', description, flags=re.IGNORECASE)
    tokenizer = RegexpTokenizer(r'\w+')
    
    # extract single word
    word_list =[]
    words = tokenizer.tokenize(description) 
    token_tag = pos_tag(words)    
    stemmer = SnowballStemmer("english")
    stopWords = set(stopwords.words('english'))  
    
    for word_pos in token_tag:
        stem_word = stemmer.stem(word_pos[0])
        if stem_word not in stopWords and word_pos[1] != 'NN':
            word_list.append(stem_word)            
                
    entity_list =extract_entity(words)    
    return (len(sent_tokenize(description)),word_list, entity_list)

# %%
# parse twitter time string to (date, timestamp_str, hour int)
# note later only timestamp_str is changed to asTYpe
def parse_time(creation_time):  
    # fcn that converts dt to date-str and time-str
    def cassandra_convert(dt):
        hour = dt.strftime("%H")
        # debug:
        base_date = datetime.date(2008,4,1)
        days_count = random.randint(1,3000)
        dt = base_date + timedelta(days=days_count)
        return (dt, str(dt),int(hour))       
        #return (dt.date(), str(dt),int(hour))
    
    dt = None
    try:
        dt = parse(creation_time)
    except Exception as e:
        # 1. log and 
        # 2.use current system time instead
        dt = datetime.datetime.now()
    return cassandra_convert(dt)

# Mapping: 1. 13 cols to 15 cols (word_list, date, 
#          timestamp, hour)
#          2. (media_ary-> media_attached; tag_ary -> tag_count)
def map_nlp_row(row):
    # return if image attached
    def check_image(media_ary):
        if media_ary is None or\
           len(media_ary) == 0:
            return False
        return True
    
    # count # of hashtags
    def count_tag(tag_ary):
        if tag_ary is None:
            return 0
        return len(tag_ary)
    
    # create a list of tuples: [(str1, like_num),] or [(str1, ret_num)] 
    def create_tuple_list(vector, num):
        result = [num]
        for item in vector:
            result.append(item)
        if len(result) == 0:
            return []
        return result
        
#     try:       
    tid = row[0]
    uid = row[1]
    tweet = row[2]
    retweet_count = row[11]
    favorite_count = row[12]
    # Map token: sentence_count, word_list
    sentence_count, word_list, entity_list\
        = process_tweet(tweet)
    # Map Time
    creation_time = row[3]
    date, timestamp, hour\
        = parse_time(creation_time)
    time_zone = row[4]
    followers_count = row[5]
    friends_count = row[6]
    city_name = row[7]
    country_name = row[8]
    media_ary = row[9]
    # boolean
    media_attached = check_image(media_ary)        
    hashtag_ary = row[10]
    # count tags
    tag_count = count_tag(hashtag_ary)
                
#     except Exception as e:
#         # 1. log e and 2.return default        
#         return Row(tid=-1, uid=-1,
#             followers_count=-1,
#             friends_count=-1,
#             tweet='n/a',retweet_count=-1,
#             favorite_count=-1,sentence_count=-1,
#             word_list=[], entity_list=[]
#             date=datetime.date(2001, 1, 1),timestamp='00:00:00',hour=0,
#             time_zone='n/a',city_name='n/a',
#             country_name='n/a',
#             media_attached=False,tag_count=-1
#             )
    
    r = Row(tid=tid, uid=uid,
            followers_count=followers_count,
            friends_count=friends_count,
            tweet=tweet,retweet_count=retweet_count,
            favorite_count=favorite_count,sentence_count=sentence_count,
            word_list=word_list, entity_list=entity_list,
            date=date,timestamp=timestamp,hour=hour,
            time_zone=time_zone,city_name=city_name,
            country_name=country_name,
            media_attached=media_attached,tag_count=tag_count
            )
    return r 
    
#base_nlp_rdd = base_rdd.map(map_nlp_row)

# %%
# base_mapped_rdd: all attributes after NLP
# base_mapped_rdd: all attributes after NLP
i_city_name=0
i_country_name=1
i_date=2
i_entity_list = 3
i_favorite_count=4
i_followers_count=5
i_friends_count=6,
i_hour=7
i_media_attached=8
i_retweet_count=9
i_sentence_count=10
i_tag_count=11
i_tid=12
i_time_zone=13
i_timestamp=14
i_tweet=15
i_uid=16
i_word_list=17

# %%
# get only interested attributes from nlp_rdd
# get only interested attributes from nlp_rdd
# get only interested attributes from nlp_rdd

#order
# uid_0, tid_1, date_2, rt_c_3, fav_c_4, word_list_5, entity_list_6
def map_time(row):
    uid_i = i_uid
    tid_i = i_tid
    rt_c_i = i_retweet_count
    fav_c_i = i_favorite_count
    word_list_i = -1
    entity_list_i = i_entity_list
    date = i_date
    # order
    return (row[uid_i],row[tid_i],row[date],
            row[rt_c_i],
            row[fav_c_i], row[word_list_i], row[entity_list_i])

# %%
import heapq
    
# get top_n for input_dic
# return a tuple of n entries
# default to 20, but can be customized
def get_top_n_dic(input_dic):
    n = 20
    top_list = heapq.nlargest(n, input_dic.items(), key=lambda x: x[1])     
    return top_list

# time_interval dic row => mapValues
def get_top_n_ti(row):
    rez_ary = []
    time_dic = row[1] 
    # key is date, v is dic_set
    for k, v in time_dic.iteritems():
        rt_top = get_top_n_dic(v[0])
        rt_entity_top = get_top_n_dic(v[1])
        fav_top = get_top_n_dic(v[2])
        fav_entity_top = get_top_n_dic(v[3])
        
        rez_ary.append((k, rt_top, rt_entity_top, fav_top, fav_entity_top))
        
    return rez_ary

# max for top_6 through all time
def get_top_6_alltime(row):
    print(len(row))
    rt_dic =  row[1]
    fav_dic = row[2]
    rt_top = get_top_6_dic(rt_dic)
    fav_top = get_top_6_dic(fav_dic)
    
    return ( rt_top, fav_top)

# %%
# 30-day time interval split, c_date vs date_base (earliest date)
def get_relative_date(date_c, date_b):
    delta = date_c - date_b
    round_days = delta.days - delta.days% 30
    relative_date = date_b + timedelta(days=round_days)
    # return string representation for storage
    return relative_date

# delta = datetime.date(2018,1,29) - datetime.date(2010,9,24)
# round_days = delta.days - delta.days % 30
# relative_date = datetime.date(2010,9,24) + timedelta(days=round_days)
# str(relative_date)
# '2018-01-15'

# %%
# helper-function for creating dictionary of {word_1: (count_int, occur_int) }
# helper-function for combineByKey time! 

def add_to_dic(dic, word, count):
    if word in dic:
        k_record = dic.get(word)
        dic.update({word: (k_record[0]+count, k_record[1]+1)})
    else:
        # word and tuple of count and # of times for word
        record = {word:(count,1)}
        dic.update(record)

# %%
# Returning 
def create_dic_set(row, rt_i=3, fav_i=4, word_list_i=5, entity_list_i = 6):  
    # helper function that updates, _list is either word_list or entity_list 
    def perform_add_op(rt_c, fav_c, rt_dic, fav_dic, _list):
        if rt_c > 0 and fav_c > 0:
            for item in _list:
                add_to_dic(rt_dic, item, rt_c)
                add_to_dic(fav_dic, item, fav_c)
        elif rt_c > 0:
            for item in _list:
                add_to_dic(rt_dic, item, rt_c)
        elif fav_c > 0 :
            for item in _list:
                add_to_dic(fav_dic, item, fav_c)
        # End
    
    rt_dic = {}
    fav_dic = {}    
    rt_entity_dic = {}
    fav_entity_dic = {}
    
    rt_c = row[rt_i]
    fav_c = row[fav_i]
    
    word_list = row[word_list_i]
    entity_list = row[entity_list_i]
    
    # Perform word_list ADD Operation
    perform_add_op(rt_c, fav_c, rt_dic, fav_dic, word_list)
    perform_add_op(rt_c, fav_c, \
                   rt_entity_dic, fav_entity_dic, entity_list)

    # return dic_set
    return (rt_dic, rt_entity_dic, fav_dic, fav_entity_dic)

# merges 2 dic together
def merge_dic(dic1, dic2):
    if len(dic1) < len(dic2):
        small_dic = dic1
        large_dic = dic2
    else:
        small_dic = dic2
        large_dic = dic1
    for k in small_dic.keys():
        # if k in small_dic
        if k in large_dic:
            # merge values together
            kv1 = small_dic.get(k)
            kv2 = large_dic.get(k)
            value = (kv1[0]+kv2[0], kv1[1]+kv1[1])
            large_dic.update({k:value})
        # simply insert to large_dic    
        else:
            large_dic.update({k:small_dic.get(k)})
    # return large_dic        
    return large_dic

# %%
# Will change to static class methods later!!
# GetTopByInterval()

###### uid_0, tid_1, date_2, rt_c_3, 
###### fav_c_4, word_list_5, entity_list_6, min_date = -1

# new value is of format dic{ k_date0: (rt_dic, fav_dic),
#                             k_date1: (rt_dic, fav_dic)}

# create_dic_set REQUIRES
#  (rt_i, fav_i, word_list_i, entity_list_i)

# process info for cCombiner_t
def parse_row_t(row):
    date = row[2]
    m_date = row[-1]
    # get k_date for dic
    k_date = get_relative_date(date, m_date)   
    tid = row[1]
    rt_dic, rt_entity_dic,\
    fav_dic, fav_entity_dic = \
        create_dic_set(row,rt_i=3,fav_i=4,\
                       word_list_i=5, entity_list_i=6)
    

    return (tid, k_date, rt_dic, rt_entity_dic,\
            fav_dic, fav_entity_dic)

# create the base combiner for this
def cCombiner_t(row):
    # handle row
    tid, k_date, rt_dic, rt_entity_dic,\
        fav_dic, fav_entity_dic = parse_row_t(row)
    
    # create dic by time ==> word_list and entity_list
    # note 4 entries as a value (in python: pointer/memory address)
    dic_set_by_time = {k_date:(rt_dic, rt_entity_dic,  \
                               fav_dic, fav_entity_dic)}             
    
    # create a list of tid
    return ([tid], dic_set_by_time)

# merges 2 dic together --> because of double pointer crap
def merge_dic_large(large_dic, small_dic):
    for k in small_dic.keys():
        # if k in small_dic
        if k in large_dic:
            # merge values together
            kv1 = small_dic.get(k)
            kv2 = large_dic.get(k)
            value = (kv1[0]+kv2[0], kv1[1]+kv1[1])
            large_dic.update({k:value})
        # simply insert to large_dic    
        else:
            large_dic.update({k:small_dic.get(k)})

# which merges V into C
def mValue_t(new_row, row):
    # update_dic operation between two dictionaries
    # large_dic_set --> (k_date, (rt_dic, rt_entity_dic, fav_dic, fav_entity_dic))
    def update_dic_op(k_date, dic_set_by_time, \
                      rt_dic, rt_entity_dic, fav_dic, fav_entity_dic):
        if k_date in dic_set_by_time:
            # large_dic ==> 4 dictionaries
            large_dic = dic_set_by_time.get(k_date)
            # merge values
            merge_dic_large(large_dic[0],rt_dic)
            merge_dic_large(large_dic[1],rt_entity_dic)
            merge_dic_large(large_dic[2],fav_dic)
            merge_dic_large(large_dic[3],fav_entity_dic)
        else:
            value_set = (rt_dic, rt_entity_dic,\
                         fav_dic, fav_entity_dic
                        )
            dic_set_by_time.update({k_date:value_set})        
            
    # handle row
    tid, k_date, rt_dic, rt_entity_dic,\
        fav_dic, fav_entity_dic = parse_row_t(row)
        
    # get dic_set_by_time    
    dic_set_by_time = new_row[1]  
    
    update_dic_op(k_date, dic_set_by_time,\
                  rt_dic, rt_entity_dic,\
                  fav_dic, fav_entity_dic)
    # add tid to the tid list
    tid_list = new_row[0]
    tid_list.append(tid)
    # return the result
    return (tid_list, dic_set_by_time)

# combine two C's (new row)
def mCombiners_t(r1, r2):
    list_merge = r1[0] + r2[0]
    
    # format: {date_k: (rt_dic, rt_entity_dic, fav_dic, fav_entity_dic)}
    dic_set_by_time1 = r1[1]
    dic_set_by_time2 = r2[1]
    
    
    # merge dic_set_by_time based on # of times each partition has
    if len(dic_set_by_time1) < len(dic_set_by_time2):
        small_t_dic = dic_set_by_time1
        large_t_dic = dic_set_by_time2
    else:
        small_t_dic = dic_set_by_time2
        large_t_dic = dic_set_by_time1
        
    for k, v in small_t_dic:
        if k in large_t_dic:
            # get corresponding dictionaries
            value_set = large_t_dic.get(k)
            for idx, dic_item in enumerate(value_set):
                # also merge the small_t_dic dictionary to dic_item 
                # in the large item
                merge_dic_large(dic_item, v[indx])                
        else:
            large_t_dic.update({k:v})
            
                                            
    return (list_merge, large_t_dic)

# %%
# from NLP rdd
# Do total count computing here: map selected ones only

# order:
# uid, tid, rt_c, fav_c, word_list, entity_list
def map_total_count(row):
    uid_i = i_uid
    tid_i = i_tid   
    rt_c_i = i_retweet_count
    fav_c_i = i_favorite_count
    word_list_i = i_word_list
    entity_list_i = i_entity_list
    
    return (row[uid_i],row[tid_i],row[rt_c_i],
            row[fav_c_i], row[word_list_i], row[entity_list_i])

# %%
# This is for total_count ==> later change to static method for class GetTop
# This is for total_count
# This is for total_count

# createCombiner (row)
def createCombiner(row):
    #print("len of createCombiner row is: ",len(row))
    rt_dic, fav_dic = create_dic_set(row,rt_i=2,fav_i=3,word_list_i=-1 )
    tid = row[1]
    # create a list of tid
    return ([tid], rt_dic, fav_dic)

# merges 2 dic together
def merge_dic(dic1, dic2):
    if len(dic1) < len(dic2):
        small_dic = dic1
        large_dic = dic2
    else:
        small_dic = dic2
        large_dic = dic1
    for k in small_dic.keys():
        # if k in small_dic
        if k in large_dic:
            # merge values together
            kv1 = small_dic.get(k)
            kv2 = large_dic.get(k)
            value = (kv1[0]+kv2[0], kv1[1]+kv1[1])
            large_dic.update({k:value})
        # simply insert to large_dic    
        else:
            large_dic.update({k:small_dic.get(k)})
    # return large_dic        
    return large_dic

# which merges V into C
def mergeValue(new_row, row):
    #retrieve last 
    rt_dic, fav_dic = create_dic_set(row,rt_i=2,fav_i=3,word_list_i=-1 )
    tid = row[1]
    
    rt_dic_merge = merge_dic(rt_dic, new_row[1])
    fav_dic_merge = merge_dic(fav_dic, new_row[2])
    
    tid_list = new_row[0]
    tid_list.append(tid)
    # return the result
    return (tid_list, rt_dic_merge, fav_dic_merge)

# combine two C's (new row)
def mergeCombiners(r1, r2):
    list_merge = r1[0] + r2[0]
    rt_dic_merge = merge_dic(r1[1], r2[1])
    fav_dic_merge = merge_dic(r1[-1], r2[-1])
    
    return (list_merge, rt_dic_merge, fav_dic_merge)

# %%
# general twitter data dump
def twitter_nlp_interface(df):
    pass

# takes df_trump data frame, do mapped conversion, and nlp conversion
# trump_nlp_rdd is where Time Interval or Overall Functions performs on
def trump_nlp_interface(df):
    trump_map_rdd = df.rdd.map(trump_mapper)
    trump_nlp_rdd = trump_map_rdd.map(map_nlp_row)
    return trump_nlp_rdd

# given nlp_rdd, map to total_count_rdd
def total_count_interface(nlp_rdd):
    total_count_rdd = nlp_rdd.map(map_total_count)    
    return total_count_rdd

# given nlp_rdd, map to time_rdd
def time_interface(nlp_rdd):
    time_rdd = nlp_rdd.map(map_time)
    return time_rdd

# given time_rdd, map each entry with minimum date
# (uid, (uid, tid, date, rt_count, fav_count, 
#  word_list, entity_list, min_date) )

def min_time_interface(time_rdd):
    # change df to have key, value with min_date at the end
    mtime_1 = time_rdd.keyBy(lambda x: x[0]).reduceByKey(lambda x, y: x if x[2] < y[2] else y)
    # (key, min_date)
    mtime_2 = mtime_1.mapValues(lambda x: x[2])
    # group min_date together 
    min_time_rdd = time_rdd.keyBy(lambda x: x[0]).join(mtime_2).mapValues(lambda x: x[0]+(x[1],) )
    return min_time_rdd

# %%
# Input: min_time_rdd
# Output: combine all together

# map out the dictionary value set and rank based on count
# save the result as well
# 

def compute_time_rdd(min_time_rdd):
    # {key = uid : (tid_list, rt_dic, rt_entity_dic, fav_dic, fav_entity_dic ) }
    c_min_time_rdd = min_time_rdd.combineByKey(cCombiner_t,mValue_t,mCombiners_t)
    return c_min_time_rdd

# Input: computed_min_time_rdd ==> list of items
# Output: (uid, (---( date, rt_dic, rt_entity_dic, av_dic, fav_entity_dic), 
#                 ()---)   ) 
# Note: ALL dics are of format: ( {word_str: (count, occur)} )
def rank_time_rdd(c_min_time_rdd):
    top_rdd = c_min_time_rdd.mapValues(get_top_n_ti)
    return top_rdd



# Input top_rdd (key_uid, value) pair ==> separate out the occurence term
#                 value is actually:  ((time, dic,....,), (time2, dic,....)
# Output: (uid, rc_wc, rc_entity_wc, fav_wc, fav_entity_wc
#               rc_wo, rc_entity_wo, fav_wo, fav_entity_wo) -->not so interesting
def transform_rank_time_rdd(top_rdd):
    # main point is to decouple (count, occur)
    def flat_map(row):
        def decouple(_list):
            w, v_pair = zip(*_list)
            count, occurence = zip(*v_pair)
            wc = list(zip(w, count))
            wo = list(zip(w, occurence))
            # return w_count, w_occurence          
            return (wc, wo)   
        # code for flat_map              
        uid = row[0]    
        creation_time = row[1][0]
        rt_list = row[1][1]
        rt_entity_list = row[1][2]
        fav_list = row[1][3]
        fav_entity_list = row[1][4]
    
        rc_wc, rc_wo = decouple(rt_list)
        rc_entity_wc, rc_entity_wo = decouple(rt_entity_list)   
        fav_wc, fav_wo = decouple(fav_list)
        fav_entity_wc, fav_entity_wo = decouple(fav_entity_list)
        
        return (uid, creation_time, \
                rc_wc, rc_entity_wc, fav_wc, fav_entity_wc,\
                rc_wo, rc_entity_wo, fav_wo, fav_entity_wo)
    # flat the value set!!!
    flat_top_rdd = top_rdd.flatMapValues(lambda x: x)
                      
    # start by mapping with helper fcn                      
    final_rdd = flat_top_rdd.map(flat_map)                      
    return final_rdd

# %%
# Build Cassandra Database Schema
# take transform_rank_time_rdd output and converts to dataframe
# can be used to save to Cassandra
def to_time_top_df(rdd):
    schema = StructType([
        StructField("uid", IntegerType(), True),  
        StructField("creation_date", DateType(), True),

        StructField("rt_word_list", ArrayType(StructType([
        StructField("word", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)     
        
        ,
        StructField("rt_entity_list", ArrayType(StructType([
        StructField("entity", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)  
        
        ,    
        StructField("fav_word_list", ArrayType(StructType([
        StructField("word", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)     
        
        ,
        StructField("fav_entity_list", ArrayType(StructType([
        StructField("entity", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)  
        
        ,
        StructField("rt_word_occur_list", ArrayType(StructType([
        StructField("word", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)     
        
        ,
        StructField("rt_entity_occur_list", ArrayType(StructType([
        StructField("entity", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)  
        
        ,    
        StructField("fav_word_occur_list", ArrayType(StructType([
        StructField("word", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)     
        
        ,
        StructField("fav_entity_occur_list", ArrayType(StructType([
        StructField("entity", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)                                 
    ])
    
    df = spark.createDataFrame(rdd, schema)
    return df


# Schema for all time top/max likes
def get_top_schema():
    pass

# %%
def save_data_frame(df, table_name):
    df.write.format("org.apache.spark.sql.cassandra").\
            mode('append').options(table=table_name,keyspace='twitter').save()

# %%
# Trump Processing
# Trump Processing
# Trump Processing


nlp_rdd = trump_nlp_interface(trump_df)
trump_time_rdd = time_interface(nlp_rdd)
# Test for min_time 
min_rdd = min_time_interface(trump_time_rdd)
rez_dic_set_rdd = compute_time_rdd(min_rdd)

top_rdd = rank_time_rdd(rez_dic_set_rdd)
rez = transform_rank_time_rdd(top_rdd)
df = to_time_top_df(rez)
save_data_frame(df, "user_top_list")

# %%
# call this function to process data into Cassandra database
def process_trump_data():
    trump_json = 's3a://twitter-data-dump/celebrities/trump.json'
    trump_df = spark.read.json(trump_json)
    
    nlp_rdd = trump_nlp_interface(trump_df)
    trump_time_rdd = time_interface(nlp_rdd)
    # Test for min_time 
    min_rdd = min_time_interface(trump_time_rdd)
    rez_dic_set_rdd = compute_time_rdd(min_rdd)

    top_rdd = rank_time_rdd(rez_dic_set_rdd)
    rez = transform_rank_time_rdd(top_rdd)
    df = to_time_top_df(rez)
    save_data_frame(df, "user_top_list")

# %%
trump_total_count_rdd = total_count_interface(trump_nlp_rdd)

# %%
trump_tc_rdd_k = trump_total_count_rdd.keyBy(lambda x: x[0])
r = trump_tc_rdd_k.combineByKey(createCombiner, mergeValue, mergeCombiners)
r.take(1)
# Out:
# [(1666,
#   ([u'955806333667807232',
#     u'955795912374267907',
#     u'955658992793149440',
#     u'955056249925750784',
#     u'954878124214415360',
#     u'954843844402647040',
#     u'954788467069870081',
#     u'954680914998648833',
#     u'954674157144477696',
#     u'954541219970977793',
#     u'954478044487520257',
#     u'954456754137501697',
#     u'954323750949982208',
#     u'954097213608570880',
#     u'954092417250222082',
#     u'953979393180950528',
#     u'953973568035086336',
#     u'953951365532876800',
#     u'953948941674078208',
#     u'953796944564031489',
#     u'953772162665590787',
#     u'953771038114045954',
#     u'953768657221451776',
#     u'953270558573154305',
#     u'953267506004754432',
#     u'952887520790040576',
#     u'952540700683497472',
#     u'952538350333939713',
#     u'952525384242876416',
#     u'952301373479104512',
#     u'952183452366929920',
#     u'952166643202916352',
#     u'951875499537641472',
#     u'951813216291708928',
#     u'951790999784783872',
#     u'951788342647107584',
#     u'951785587765280768',
#     u'951679619341737986',
#     u'951675713089888256',
#     u'951650274032209920',
#     u'951648197440569344',
#     u'951647402599026689',
#     u'951596346011680768',
#     u'951457382651056128',
#     u'951431836030459905',
#     u'951416674808467461',
#     u'951309956720087041',
#     u'951236634095308800',
#     u'951204878562549767',
#     u'951184020150382592',
#     u'951109942685126656',
#     u'951106475254059008',
#     u'951094078661414912',
#     u'950946293077209088',
#     u'950866561153331202',
#     u'947592785519173637',
#     u'947588263103139841',
#     u'947461470924820480',
#     u'947453152806297600',
#     u'947235015343202304',
#     u'947213895286054914',
#     u'947180713236934657',
#     u'946949708915924994',
#     u'946731576687235072',
#     u'946728546633953285',
#     u'946724075157651457',
#     u'946531657229701120',
#     u'946401576381505536',
#     u'946201376652169220',
#     u'946156544927977477',
#     u'946151080546750465',
#     u'945780569388015616',
#     u'945646491955290113',
#     u'945624910898122752',
#     u'945030174290186241',
#     u'944927689638662145',
#     u'944906847970119680',
#     u'944703626454487042',
#     u'944700332881440769',
#     u'944665687292817415',
#     u'944222157218942978',
#     u'944210183089254400',
#     u'944192071535153152',
#     u'944187730564714497',
#     u'943856675294982145',
#     u'943819430735372289',
#     u'943521141062238208',
#     u'943489378462130176',
#     u'943362605258813441',
#     u'943135588496093190',
#     u'943079382163353600',
#     u'942857031693799425',
#     u'942851788461563906',
#     u'942840800853024770',
#     u'942829676699021312',
#     u'942827072824672262',
#     u'942717030091943936',
#     u'942551516564639744',
#     u'942439739264831488',
#     u'942044657613230080',
#     u'941789515248750592',
#     u'941756992070307845',
#     u'941406242785955841',
#     u'941404173433794561',
#     u'941400670766321666',
#     u'941353395121741825',
#     u'940930017365778432',
#     u'940904649728708609',
#     u'940795587733151744',
#     u'940584383605563392',
#     u'940567812053053441',
#     u'940554567414091776',
#     u'940223974985871360',
#     u'939967625362276354',
#     u'939849867438034944',
#     u'939680422493073408',
#     u'939634404267380736',
#     u'939616077356642304',
#     u'939564681743814661',
#     u'939560154269405184',
#     u'939485131693322240',
#     u'939480342779580416',
#     u'939477807813595136',
#     u'939355447273906182',
#     u'939208571253862400',
#     u'939152197090148352',
#     u'939149296389251072',
#     u'938878398608433152',
#     u'938873956345499654',
#     u'938804374079459329',
#     u'938517073508163584',
#     u'938440878577856512',
#     u'938102355878440960',
#     u'937652739001212928',
#     u'937641904338063361',
#     u'937309279257792512',
#     u'937145025359761408',
#     u'937142713211813889',
#     u'937141061343956992',
#     u'937007006526959618',
#     u'936941673124425728',
#     u'936864840240398337',
#     u'936713881711529986',
#     u'936688444046266368',
#     u'936555753946705920',
#     u'936551346299338752',
#     u'936395008139198464',
#     u'936393574433939456',
#     u'936339260218724353',
#     u'936260193536573440',
#     u'936209447747190784',
#     u'936039501474025473',
#     u'936037938898636800',
#     u'936032275980079104',
#     u'936014271858831361',
#     u'936005585019002887',
#     u'935940131311190021',
#     u'935883355547160577',
#     u'935874566701842434',
#     u'935870484146683904',
#     u'935844881825763328',
#     u'935701139198181376',
#     u'935686205429157888',
#     u'935640578007687168',
#     u'935513049729028096',
#     u'935493619204620288',
#     u'935489831005810688',
#     u'935152378747195392',
#     u'935147410472480769',
#     u'934961858380955648',
#     u'934896989539586054',
#     u'934781939088629761',
#     u'934551607596986368',
#     u'934539256940417024',
#     u'934189999045693441',
#     u'934131805409697792',
#     u'934080974773776384',
#     u'934031535757582336',
#     u'934029886842458112',
#     u'934026050388013056',
#     u'933837062293291008',
#     u'933658521828315136',
#     u'933301876975718401',
#     u'933285973277868032',
#     u'933282274937733126',
#     u'933280234220134401',
#     u'933105158275325952',
#     u'932570628451954688',
#     u'932392209445457920',
#     u'932388590344196096',
#     u'932303108146892801',
#     u'931877599034388480',
#     u'931538234169069568',
#     u'931254609041068032',
#     u'930346433177378817',
#     u'930305984077156352',
#     u'930304414564352000',
#     u'930089374187950081',
#     u'929509950811881472',
#     u'929503641014112256',
#     u'928936220360503296',
#     u'928933135806488577',
#     u'928931835664465921',
#     u'928926863375794176',
#     u'928922787938385920',
#     u'928918183104225280',
#     u'928770248370728960',
#     u'928769154345324544',
#     u'928267692645036032',
#     u'928097817037627393',
#     u'928097146993369088',
#     u'928074747316928513',
#     u'928064591665467393'],
#    {u'amp inspire Americans': (26460, 1),
#     u'votes': (64913, 2),
#     u'The American public': (41062, 1),
#     u'MUCH': (27652, 1),
#     u'great country': (107824, 1),
#     u'SenateMajLdr Mitch McConnell': (34648, 1),
#     u'MAKING AMERICA GREAT AGAIN MAGA': (52110, 1),
#     u'a shame': (63290, 1),
#     u'President Trump': (50480, 1),
#     u'SenateMajLdr McConnell': (26106, 1),
#     u'a phony photo': (49072, 1),
#     u'Remember Republicans': (38414, 1),
#     u'Firefighters paramedics': (36928, 1),
#     u'The Chinese Envoy': (33814, 1),
#     u'no clue': (58718, 1),
#     u'Military': (24088, 1),
#     u'OUR WORKERS': (23062, 1),
#     u'National Anthem Weak': (41062, 1),
#     u'Economists': (15817, 1),
#     u'companies': (93746, 2),
#     u'TANKED': (548, 1),
#     u'jamiejmcintyre': (12128, 1),
#     u'South Korea': (21964, 1),
#     u'leaders': (23532, 1),
#     u'The Fake News': (66440, 1),
#     u'President Recep Tayyip Erdogan': (32300, 1),
#     u'the Presidential Election': (44174, 1),
#     u'an off location': (60158, 1),
#     u'the mess': (32300, 1),
#     u'the Tax Cuts': (62856, 1),
#     u'Amazon': (27652, 1),
#     u'a big beautiful Christmas': (25084, 1),
#     u'safety DACA': (46060, 1),
#     u'the Senate': (267012, 2),
#     u'no NBA contract': (78094, 1),
#     u'Great Military': (46448, 1),
#     u'much Fake News Check': (52588, 1),
#     u'this moment': (36800, 1),
#     u'another shot': (49878, 1),
#     u'Shoplifting': (30318, 1),
#     u'provision becomes simpler': (32196, 1),
#     u'the lives': (59028, 1),
#     u'employees': (25145, 2),
#     u'week extension': (26106, 1),
#     u'reports': (50342, 1),
#     u'the Staff': (20106, 1),
#     u'NOT': (66963, 2),
#     u'a fraud': (74954, 1),
#     u'campaign': (52290, 2),
#     u'fight fight fight': (42980, 1),
#     u'real economics': (33406, 1),
#     u'National Anthem Great': (75212, 1),
#     u'Healthy New Year': (79396, 1),
#     u'the interests': (22414, 1),
#     u'all Countries': (33900, 1),
#     u'political career anyway': (33064, 1),
#     u'MORE TO COME': (62696, 1),
#     u'a Great Wall': (59028, 1),
#     u'any other President': (45456, 1),
#     u'the phony Democrat excuse': (69616, 1),
#     u'that day': (44334, 1),
#     u'best reading': (19212, 1),
#     u'a day Wrong': (68036, 1),
#     u'the day Trump': (63668, 2),
#     u'rights': (60821, 1),
#     u'the bonds': (18970, 1),
#     u'poor decision': (46054, 1),
#     u'LAST thing': (39640, 1),
#     u'many outlets': (74954, 1),
#     u'end': (19035, 1),
#     u'Numbers Lowest Unemployment': (57372, 1),
#     u'The Wall': (99536, 2),
#     u'FAKE NEWS WaPo': (49072, 1),
#     u'all Americans': (112118, 2),
#     u'the WhiteHouse Bahrain': (21038, 1),
#     u'the Tax Cut Bill': (66368, 2),
#     u'mess': (42742, 1),
#     u'Grand Staircase Escalante': (29494, 1),
#     u'other countries': (131858, 1),
#     u'West Palm Beach Fire amp Rescue': (36928, 1),
#     u'a day': (57756, 1),
#     u'weak borders': (52176, 1),
#     u'Donald Trump Big stuff Deep State Give': (47648, 1),
#     u'order': (125210, 2),
#     u'operations': (24745, 1),
#     u'big companies': (44632, 1),
#     u'great support': (32196, 1),
#     u'office': (100801, 2),
#     u'the Pacific': (27722, 1),
#     u'FLOTUS Melania': (26064, 1),
#     u'The massive TRADE deficits': (33900, 1),
#     u'ECONOMY': (15817, 1),
#     u'the next level': (48898, 1),
#     u'Excellent preliminary meeting': (26106, 1),
#     u'humanity Whatever': (97282, 1),
#     u'The Christmas Story': (97282, 1),
#     u'the election': (125456, 2),
#     u'stalemate': (47531, 1),
#     u'the Fake Mainstream Media': (38070, 1),
#     u'a wonderful relationship': (73220, 1),
#     u'many great American workers': (49490, 1),
#     u'many beautiful JOBS': (29082, 1),
#     u'the election Russia Russia Russia': (69616, 1),
#     u'victory': (19820, 1),
#     u'side': (38113, 2),
#     u'regs rules': (25708, 1),
#     u'SecretaryAcosta USDOL': (36182, 1),
#     u'big amp': (33698, 1),
#     u'ASEAN50': (8566, 1),
#     u'Wow': (29405, 1),
#     u'crimes': (35841, 1),
#     u'Mainstream Meadia': (58810, 1),
#     u'the pleasure': (22896, 1),
#     u'Government Funding Bill': (52176, 1),
#     u'no big deal': (154162, 1),
#     u'a new Executive Order': (38962, 1),
#     u'a Pelosi Schumer Puppet Roy Moore': (43180, 1),
#     u'the fact': (154092, 2),
#     u'The Russian Collusion Hoax': (53184, 1),
#     u'Tax Cut Bill': (41312, 1),
#     u'Points USA Sadly': (38070, 1),
#     u'months Lowest': (107824, 1),
#     u'Circuit': (26665, 1),
#     u'THANK YOU Pensacola Florida': (42980, 1),
#     u'Many people': (66726, 1),
#     u'Reform Fiat Chrysler': (38370, 1),
#     u'Clinton': (22798, 1),
#     u'Chain': (21731, 1),
#     u'size Immediate expensing': (29082, 1),
#     u'days': (43467, 2),
#     u'this year': (72272, 2),
#     u'an incredible victory': (16784, 1),
#     u'every new supersonic jet': (26460, 1),
#     u'The USA': (60824, 1),
#     u'a place': (22896, 1),
#     u'service': (31329, 2),
#     u'Republicans Democrats': (46448, 1),
#     u'massive negative Trump coverage amp Russia hoax': (46368, 1),
#     u'big deal': (138730, 2),
#     u'Haiti': (36610, 1),
#     u'the Southern Border': (129444, 2),
#     u'the WrightBrothers': (26460, 1),
#     u'a big win': (46448, 1),
#     u'Beautiful': (53912, 1),
#     u'The voters': (52044, 1),
#     u'anemic polls': (33064, 1),
#     u'preparation': (39791, 1),
#     u'See': (23224, 1),
#     u'a mistake': (32300, 1),
#     u'appropriate civic community': (53090, 1),
#     u'the year': (56182, 2),
#     u'The Mainstream Media': (69624, 1),
#     u'mine': (11207, 1),
#     u'ratings way': (75212, 1),
#     u'the Failing nytimes': (68036, 1),
#     u'strength': (14510, 1),
#     u'unpopular Indiv Mandate': (33056, 1),
#     u'big way Congratulations': (73254, 1),
#     u'a massive tax cut': (61884, 2),
#     u'Jones': (26497, 1),
#     u'Fake News': (190302, 2),
#     u'such horrible conditions Russia': (33814, 1),
#     u'the top executives': (52588, 1),
#     u'past Admins': (58718, 1),
#     u'no collusion everybody': (57610, 1),
#     u'Jerusalem': (39791, 1),
#     u'the story': (97282, 1),
#     u'hard dream': (33698, 1),
#     u'great Supreme Court Justice RECORD CUT IN REGS': (88770, 1),
#     u'Election': (91249, 2),
#     u'the man': (72350, 1),
#     u'a little bit': (131858, 1),
#     u'many other things': (34184, 1),
#     u'the only way': (159494, 2),
#     u'law enforcement families God Bless': (34086, 1),
#     u'the Justice Department': (66726, 1),
#     u'meetings': (30787, 2),
#     u'profitability': (25240, 1),
#     u'Country Senate Republicans': (34184, 1),
#     u'foreign intelligence collection': (55832, 1),
#     u'solutions': (13053, 1),
#     u'a great game today USArmy': (21984, 1),
#     u'ridiculous Lottery System': (70416, 1),
#     u'amp retraction': (49072, 1),
#     u'Iranian govt': (121642, 1),
#     u'many more companies': (50290, 2),
#     u'Republicans': (139423, 2),
#     u'the economy Tax Cut': (50480, 1),
#     u'foreign surveillance': (24846, 1),
#     u'the uniform': (44334, 1),
#     u'the C R TODAY': (42004, 1),
#     u'big payments': (51488, 1),
#     u'foreign bad guys': (24846, 1),
#     u'television': (34018, 1),
#     u'Taxes': (37676, 2),
#     u'high crime': (43462, 1),
#     u'Moore': (19207, 1),
#     u'countries': (48816, 2),
#     u'gov t': (47794, 1),
#     u'collusion': (22740, 1),
#     u'gross incompetence': (47714, 1),
#     u'disaster': (548, 1),
#     u'another year': (50688, 1),
#     u'a reciprocal fashion': (33900, 1),
#     u'the Democrats': (302174, 2),
#     u'last year': (87834, 1),
#     u'Social Media': (159494, 2),
#     u'great honor': (192392, 2),
#     u'The United States Senate': (64124, 1),
#     u'Dr King': (53090, 1),
#     u'the Crown Prince': (42076, 2),
#     u'OCare': (16528, 1),
#     u'today APEC2017': (22414, 1),
#     u'an unforgettable afternoon': (26064, 1),
#     u'the washingtonpost': (50700, 1),
#     u'LaVar': (39047, 1),
#     u'FBI Deputy Director Andrew McCabe': (72350, 1),
#     u'defiance': (10458, 1),
#     u'packages': (27652, 1),
#     u'foes': (13861, 1),
#     u'country': (293021, 2),
#     u'the Locker Room': (50994, 1),
#     u'the horror': (17132, 1),
#     u'players': (20531, 1),
#     u'single reason': (25708, 1),
#     u'the unsolved mystery': (54206, 2),
#     u'an END': (70416, 1),
#     u'Sen Jeff Flake y': (33064, 1),
#     u'the corporate income tax rate': (33406, 1),
#     u'a result': (87442, 2),
#     u'popular Tax Cut': (44632, 1),
#     u'Biggest Tax Bill': (56820, 1),
#     u'gratitude': (12949, 1),
#     u'unfair press': (100684, 1),
#     u'the Fake News Media remember': (57432, 1),
#     u'the results': (36424, 1),
#     u'JBA_NAFW': (8392, 1),
#     u'a Special Election March': (34228, 1),
#     u's corruption': (121642, 1),
#     u'America God Bless': (44334, 1),
#     u'Luther Strange': (30470, 1),
#     u'Government OPEN': (42004, 1),
#     u'American history': (57610, 1),
#     u'life': (216215, 2),
#     u'CH': (14587, 1),
#     u'families': (17324, 1),
#     u'drugs': (96805, 2),
#     u'Did Dems': (45596, 1),
#     u'Trump Campaign Did FBI use Intel tool': (45596, 1),
#     u'k s': (44444, 1),
#     u'actual dollars': (32196, 1),
#     u'Secretary': (28716, 1),
#     u'commerce': (9485, 1),
#     u'Many reports': (121642, 1),
#     u'GOD BLESS AMERICA LESM': (34086, 1),
#     u'Hillary Clinton': (59508, 1),
#     u'employ': (36627, 1),
#     u'voice': (21490, 1),
#     u'dollar Wall': (56352, 1),
#     u'controversial FISA ACT today': (34548, 1),
#     u'income cuts': (33056, 1),
#     u'MASSIVE tax cuts': (34648, 1),
#     u'a new idea': (50994, 1),
#     u'the Vice President': (63290, 1),
#     u'contempt citations': (47648, 1),
#     u'Turkey call': (31212, 1),
#     u'bipartisan members': (27562, 1),
#     u'both Bears Ears': (29494, 1),
#     u'President': (28878, 1),
#     u'inventors': (16849, 1),
#     u'prosperity': (35540, 2),
#     u'a long amp': (38070, 1),
#     u'famous FBI holiday interrogation': (87862, 1),
#     u'U S employees': (38370, 1),
#     u'a new high unemployment': (23774, 1),
#     u'thoughts': (29256, 2),
#     u'Obstruct': (18924, 1),
#     u'the USA': (129478, 2),
#     u'a hard fought victory': (49878, 1),
#     u'a poor man': (66366, 1),
#     u'THERE IS MUCH': (62696, 1),
#     u'consumer sentiment': (19212, 1),
#     u'greatest honor': (26320, 1),
#     u'growth All Trump': (50480, 1),
#     u'investments': (40161, 1),
#     u'a deal': (242424, 2),
#     u'Thank': (10053, 1),
#     u'unemployment': (22728, 1),
#     u'the rules': (33900, 1),
#     u'The world cannot': (67732, 1),
#     u'Crime': (60947, 2),
#     u'amnesty amp illegal immigration': (47794, 1),
#     u'dangerous Lottery': (48176, 1),
#     u'the misspelled reset button Obama': (57432, 1),
#     u'the Marine Corps Air Facility': (36760, 1),
#     u'unpopular Individual Mandate': (87754, 2),
#     u'phony Dossier': (34548, 1),
#     u'powerful representative': (29890, 1),
#     u'a Liberal Democrat': (39640, 1),
#     u'the Obstructionist Democrats': (37286, 1),
#     u'first year': (45456, 1),
#     u'final stop': (17132, 1),
#     u'St Charles Missouri': (16784, 1),
#     u'innocent': (33866, 1),
#     u'an entire Nation THANK YOU': (86388, 2),
#     u'Chrysler': (76789, 4),
#     u'many billions': (55304, 1),
#     u'heavy truck production': (38370, 1),
#     u'security': (75749, 2),
#     u'Justice Gorsuch': (50700, 1),
#     u'Human Rights': (56256, 1),
#     u'right': (60821, 1),
#     u'amp reform': (33056, 1),
#     u'people': (323951, 2),
#     u'sure great credit': (40028, 1),
#     u'the Great State': (33064, 1),
#     u'OUR COMMUNITIES': (23062, 1),
#     u'Much': (29405, 1),
#     u'a final bill': (34648, 1),
#     u'Nobody': (13019, 1),
#     u't hold troop funding hostage': (47794, 1),
#     u'everything': (13781, 1),
#     u'foreign land': (24846, 1),
#     u'Fines': (22929, 1),
#     u'The Democrats': (177620, 2),
#     u'the Mississippi State History Museum': (29688, 1),
#     u'Matt Lauer': (54206, 2),
#     u'a phenomenon': (44632, 1),
#     u'the AMERICAN PEOPLE': (26320, 1),
#     u'no Deal': (58122, 1),
#     u'manufacturing': (18091, 1),
#     u'all cost': (70416, 1),
#     u'a Dem defund': (48898, 1),
#     u'dollars': (157477, 2),
#     u'months': (44508, 2),
#     u'President Xi Jinping': (29890, 1),
#     u'Cut': (16528, 1),
#     u'a lower corporate tax rate': (31634, 1),
#     u'son': (179629, 2),
#     u'horrendously inaccurate': (55826, 1),
#     u'SUV': (36627, 1),
#     u'massive amounts': (49072, 1),
#     u'league Players': (30650, 1),
#     u'a century': (26460, 1),
#     u'all Women': (107824, 1),
#     u'the policies': (38632, 1),
#     u'the Internet': (56256, 1),
#     u'the National Anthem': (50994, 1),
#     u'support': (19481, 1),
#     u'Ed Gillespie': (38768, 1),
#     u'American business': (49194, 1),
#     u'fought': (22167, 1),
#     u'way': (24536, 1),
#     u'NBC': (53397, 2),
#     u'Congratulations': (91604, 2),
#     u'Gun Owners': (43180, 1),
#     u'January': (26545, 1),
#     u'the disrespect': (71712, 2),
#     u'Florida Honestly': (44478, 1),
#     u'Iranian citizens': (121642, 1),
#     u'the Washington Post': (48544, 1),
#     u'the Stock Market': (75184, 1),
#     u'the good news': (22896, 1),
#     u'fellow American s SAFE Everyone': (27644, 1),
#     u'Tax Cuts House Republicans': (42004, 1),
#     u'big dreams': (52110, 1),
#     u'unprecedented economic success': (107824, 1),
#     u'much Fake News': (69624, 1),
#     u'Pensacola': (24272, 1),
#     u'the TAX CUTS': (31634, 1),
#     u'the House': (84608, 2),
#     u'Pennsylvania today': (34228, 1),
#     u'trip': (30079, 1),
#     u'regime': (60821, 1),
#     u'a fantastic job': (56306, 2),
#     u'illegal immigration Border Wall Military Pro Life V A Judges': (52994,
#      1),
#     u'Massive Alaska Drilling': (46442, 1),
#     u'that important Alabama Senate seat Need': (27828, 1),
#     u'papers': (27913, 1),
#     u'preventable crime': (70708, 1),
#     u'the victims': (17784, 1),
#     u'The Dems': (167160, 2),
#     u'Virginia candidate': (33858, 1),
#     u'the scene': (30482, 1),
#     u'intent': (29514, 1),
#     u'a great year': (130084, 2),
#     u'Dossier FBI CANNOT': (71256, 1),
#     u'another RECORD HIGH unemployment': (57718, 1),
#     u'the good': (56164, 1),
#     u'the Repeal': (46442, 1),
#     u'the FBI': (198800, 2),
#     u'mountains wastelands': (43184, 1),
#     u'LiAngelo': (77081, 1),
#     u'grief amp': (29174, 1),
#     u'fact': (61749, 2),
#     u'time': (144858, 2),
#     u'the capital': (79582, 1),
#     u'all prosper side': (22896, 1),
#     u's Together WE': (31472, 1),
#     u'the USA Really': (57718, 1),
#     u'mistake Watch': (47714, 1),
#     u'Today': (201177, 2),
#     u'amp independent nations': (22896, 1),
#     u'Trump Russia': (45480, 1),
#     u'A story': (50700, 1),
#     u'charge': (36175, 1),
#     u'amp Lottery': (43462, 1),
#     u'Dishonest reporting': (75184, 1),
#     u'advantage': (58718, 2),
#     u'workers Dems': (51488, 1),
#     u'the President': (42166, 1),
#     u'ISIS fighters': (63668, 2),
#     u'America Special thanks': (34648, 1),
#     u'LaVar Should': (60636, 1),
#     u'travels': (11448, 1),
#     u'the first day': (112800, 2),
#     u'team': (18100, 1),
#     u'November Market': (1096, 1),
#     u'giant step': (16784, 1),
#     u'American families': (20330, 1),
#     u'Rick': (17114, 1),
#     u'the United States': (265778, 2),
#     u'Election Highest Stock Market EVER Jobs': (44444, 1),
#     u'Consumer Confidence': (44174, 1),
#     u'Fake News CNN Their slogan': (74954, 1),
#     u's vote': (24846, 1),
#     u'Democrat Dianne Feinstein': (46054, 1),
#     u'America Chrysler': (49194, 1),
#     u'DuPont Washington Thank': (30482, 1),
#     u'the fix': (24846, 1),
#     u'water': (21592, 1),
#     u'a group': (43462, 1),
#     u'change': (23532, 1),
#     u'innovate amp': (33698, 1),
#     u'tire': (13230, 1),
#     u'hard work': (56820, 1),
#     u'MS': (19891, 1),
#     u'TAX CUTS Huge win': (49072, 1),
#     u'love': (22316, 1),
#     u'the arena': (48544, 1),
#     u'the honor': (22896, 1),
#     u'a Shutdown': (88894, 2),
#     u'wealth': (91233, 2),
#     u'the NFL': (41062, 1),
#     u'visit': (10519, 1),
#     u'the tragic terrorist attack': (42166, 1),
#     u'Trump Pence Plenty': (52044, 1),
#     u'a long term prison sentence IT WAS ME Too': (66366, 1),
#     u'Hillary Emails': (45596, 1),
#     u'the care': (38962, 1),
#     u'scope': (14541, 1),
#     u'AMERICA': (41292, 2),
#     u'today': (12423, 1),
#     u'a cold': (46054, 1),
#     u'The U S': (29020, 1),
#     u'October': (9606, 1),
#     u'F': (10519, 1),
#     u'Excluding hurricane effects CEA': (23774, 1),
#     u'Eve': (65929, 1),
#     u'important partners': (21038, 1),
#     u'JOBS Stock Market': (50688, 1),
#     u'all time Record': (44174, 1),
#     u'The North Korean regime': (20916, 1),
#     u'behalf': (68101, 2),
#     u'a disgrace Must': (45480, 1),
#     u'Lightweight Senator Kirsten Gillibrand': (47332, 1),
#     u'the false accusations': (76312, 1),
#     u'SenSchumer': (13053, 1),
#     u'nuclear amp ballistic missile programs': (20916, 1),
#     u'Make America Great Again Jones': (27828, 1),
#     u'DNC servers': (45596, 1),
#     u'Putin': (28716, 1),
#     u'a bad thing': (79254, 1),
#     u'General Flynn': (151152, 2),
#     u'greater control': (17488, 1),
#     u'the finish line': (16784, 1),
#     u'economy': (160017, 2),
#     u'Unprecedented success': (57372, 1),
#     u'good news': (57718, 1),
#     u'Rigged system': (87862, 1),
#     u'sacrifice': (42321, 2),
#     u'THE MEN AND WOMEN IN BLUE Thank': (34086, 1),
#     u'the stock market Jobs': (49194, 1),
#     u'exploration amp innovation': (26460, 1),
#     u'heroes': (14844, 1),
#     u'certain subjects': (45146, 1),
#     u'a bad joke': (56352, 1),
#     u'The Tax Cut Bill': (66380, 2),
#     u'untrue stories Hence': (58810, 1),
#     u'many millions': (151496, 2),
#     u'the economy': (101256, 2),
#     u'numerous occasions': (45480, 1),
#     u'ones': (35354, 1),
#     u'jail': (107399, 2),
#     u'The end result': (34184, 1),
#     u'freedom equality justice': (29688, 1),
#     u'WANTS TO RAISES TAXES TO THE SKY Jones': (53604, 1),
#     u'talk': (19035, 1),
#     u'years': (371083, 2),
#     u'the message': (22414, 1),
#     u's life': (53090, 1),
#     u'terrorism Looks': (60824, 1),
#     u'the extremist ideology': (67732, 1),
#     u'Jobs Jobs Jobs': (36424, 1),
#     u'Hispanics': (18091, 1),
#     u'the world': (253312, 2),
#     u'P M': (64124, 1),
#     u'square miles': (127336, 4),
#     u'Great news': (46170, 1),
#     u'the nation': (121642, 1),
#     u'conversations': (22667, 1),
#     u'The NFL': (50994, 1),
#     u'DaveWeigel WashingtonPost': (49072, 1),
#     u'nation': (64380, 2),
#     u'BASE': (33220, 1),
#     u'Big Luther Strange': (33858, 1),
#     u'Tax Cut money': (1096, 1),
#     u'accomplishments': (19035, 1),
#     u'FAKE NEWS': (172158, 2),
#     u'ISIS Judicial Strength': (57372, 1),
#     u'year': (51587, 2),
#     u'the State Department': (145948, 2),
#     u'deepest sympathies': (17784, 1),
#     u'living': (16907, 1),
#     u'a FAKE fraud': (48544, 1),
#     u'Michigan': (95974, 2),
#     u'Fake News CNN': (47714, 1),
#     u'a Bipartisan fashion Infrastructure': (56164, 1),
#     u'Doug Jones': (49878, 1),
#     u'investigation': (36175, 1),
#     u'the INTERDICTAct H R': (27562, 1),
#     u'an empty arena hours': (49072, 1),
#     u'cars': (36627, 1),
#     u'ISIS': (40161, 1),
#     u'Security': (44481, 2),
#     u'remainder': (37606, 1),
#     u'care': (55916, 2),
#     u'these levels': (44174, 1),
#     u'secret committee testimony': (46054, 1),
#     u'the leaders': (22414, 1),
#     u'This issue': (50994, 1),
#     u'The biggest loser': (48176, 1),
#     u'place': (81015, 2),
#     u'Asia': (16950, 1),
#     u'sovereign': (11448, 1),
#     u'The only people': (37286, 1),
#     u'vote': (114439, 4),
#     u'corporations': (22316, 1),
#     u'the Mexican Anthem': (75212, 1),
#     u'caught': (22929, 1),
#     u'prayers': (29256, 2),
#     u'Bundle': (65929, 1),
#     u'dollars Bad deal': (60158, 1),
#     u'Republicans Senators': (35680, 1),
#     u'friend': (44215, 2),
#     u'The single greatest Witch Hunt': (57610, 1),
#     u'the safety': (113954, 2),
#     u'the end': (32432, 1),
#     u'the rest': (33056, 1),
#     u'a massive plant': (52044, 1),
#     u'Reform Bill Terrible Individual Mandate ObamaCare Repealed Goes': (64124,
#      1),
#     u'a nation': (33698, 1),
#     u'Border Security': (74214, 2),
#     u'David Bossie': (45072, 1),
#     u'first responders': (36928, 1),
#     u'A big contingent': (27828, 1),
#     u'Seven': (23417, 1),
#     u'tough rivers': (43184, 1),
#     u'amp Democrats': (26038, 1),
#     u'bogus Clinton Campaign DNC': (71256, 1),
#     u'ALL YEAR LONG': (57756, 1),
#     u'The Bill': (35680, 1),
#     u'Court': (14587, 1),
#     u'economic security IS': (28822, 2),
#     u'Shutdown politics': (85484, 1),
#     u'highest Stock Market EVER Military': (88770, 1),
#     u'voices': (18400, 1),
#     u'a NATION': (52110, 1),
#     u'the vile criminal cartel MS13': (39782, 1),
#     u'The enactment': (31634, 1),
#     u'next trip': (60636, 1),
#     u'The fact': (45480, 1),
#     u's friends': (27722, 1),
#     u'the past amp dedicate': (29688, 1),
#     u'a Trumper': (33858, 1),
#     u'the people': (138960, 2),
#     u'last legs': (29174, 1),
#     u'year reviews': (38070, 1),
#     u'Amazon richer': (55304, 1),
#     u'no task': (33698, 1),
#     u'Rex Tillerson': (45146, 1),
#     u'RICK SACCONE': (34228, 1),
#     u'This GREAT AMERICAN SPIRIT': (26460, 1),
#     u'a comprehensive overhaul complete': (31634, 1),
#     u'Don King': (66366, 1),
#     u'pages': (52208, 2),
#     u'CUT TAXES': (23062, 1),
#     u'the WhiteHouse': (19140, 1),
#     u'Merit': (29514, 1),
#     u'Good Republican candidates': (33858, 1),
#     u'a total flunky': (47332, 1),
#     u'rating': (23184, 1),
#     u'WE': (34812, 1),
#     u'next generation': (26460, 1),
#     u'the Rep House': (33056, 1),
#     u'the Wall': (159428, 2),
#     u'representatives': (18464, 1),
#     u'Fake Polls': (66440, 1),
#     u'Time Magazine': (87834, 1),
#     u'crime': (48719, 2),
#     u'the Fake News': (140510, 2),
#     u'the first place': (32300, 1),
#     u'Crooked Hillary AFTER': (66726, 1),
#     u'a lifetime opportunity': (25848, 1),
#     u'The White House': (64124, 1),
#     u'full term': (62696, 1),
#     u'means nothing': (61744, 1),
#     u'fabricated stories': (76312, 1),
#     u'MERRY CHRISTMAS': (57756, 1),
#     u'the damages': (75184, 1),
#     u'Tax cut money': (49194, 1),
#     u'miles': (13160, 1),
#     u'a perfect place': (56164, 1),
#     u'last time': (31472, 1),
#     u'vision': (11448, 1),
#     u'the Border': (95062, 1),
#     u'solemn tribute': (29688, 1),
#     u'Wishbone': (14850, 1),
#     u'big week': (34184, 1),
#     u'a disaster': (91452, 2),
#     u'The Pelosi Schumer Puppet Jones': (39640, 1),
#     u'the transition': (63290, 1),
#     u'no challenge': (33698, 1),
#     u'squandering': (60821, 1),
#     u'the birth': (97282, 1),
#     u'an unexpected new source': (44632, 1),
#     u'highest civilian honor': (30998, 1),
#     u'human rights violations': (60824, 1),
#     u'The Kate Steinle killer': (71682, 1),
#     u'jobs': (93914, 2),
#     u'The Stock Market': (45456, 1),
#     u'Fake reporting': (20106, 1),
#     u'a double standard': (87862, 1),
#     u'a SHUTDOWN': (42004, 1),
#     u'a shutdown': (47794, 1),
#     u'wonderful First Responders': (30482, 1),
#     u'this Crooked Hillary pile': (71256, 1),
#     u'big unnecessary regulation cuts': (38632, 1),
#     u'tour': (16950, 1),
#     u'last night': (173026, 2),
#     u'California s wildfires': (28030, 1),
#     u'dishonest corrupt': (83530, 1),
#     u'duty': (29514, 1),
#     u'a good thing': (79254, 1),
#     u'extraordinary museums': (29688, 1),
#     u'The write': (49878, 1),
#     u'Norway': (9570, 1),
#     u'biased media': (80322, 1),
#     u'the historic milestones': (107824, 1),
#     u'this information NOW FoxNews': (47648, 1),
#     u'the Fake Book': (69624, 1),
#     u'the dumbest man': (68036, 1),
#     u'cities': (35354, 1),
#     u'drug addiction': (27562, 1),
#     u'Packed house': (49072, 1),
#     u'a Lago': (31212, 1),
#     u'Vets': (44385, 1),
#     u'Melania': (18592, 1),
#     u'the contract': (54206, 2),
#     u'borders': (22222, 1),
#     u'President Xi': (21964, 1),
#     u'incredible work': (28030, 1),
#     u'the biggest corporate rate cut': (33406, 1),
#     u'the dawn': (36800, 1),
#     u'overdose': (13781, 1),
#     u'country trillions': (25708, 1),
#     u'the horrible Chain Migration': (70416, 1),
#     u'Commander': (18380, 1),
#     u'final vote': (64124, 1),
#     u'policies': (50571, 2),
#     u'evening': (13032, 1),
#     u'Crime WEAK': (53604, 1),
#     u'Israel': (39791, 1),
#     u'author': (34812, 1),
#     u'U S Michigan': (1096, 1),
#     u's': (55614, 2),
#     u'surveillance': (23824, 1),
#     u'speech': (24272, 1),
#     u'finest embassy': (60158, 1),
#     u'the number': (58122, 1),
#     u'M Clinton Puppet': (59508, 1),
#     u'The good news': (62696, 1),
#     u'a huge pro growth stimulus': (33406, 1),
#     u'Toyota': (23085, 1),
#     u'the national monuments designations': (29494, 1),
#     u'great political victory': (21964, 1),
#     u'The Dow': (44174, 1),
#     u'the Roosevelt Room': (25708, 1),
#     u'much look': (21964, 1),
#     u'North Korea Syria Ukraine terrorism': (79254, 1),
#     u'beautiful list': (38070, 1),
#     u'the flow': (27562, 1),
#     u'nothing happens': (87862, 1),
#     u'The Tax Cut Reform Bill': (46442, 1),
#     u'money': (92540, 2),
#     u'SOVEREIGN': (8744, 1),
#     u'actions': (31645, 1),
#     u'much loss': (42166, 1),
#     u'TAX REFORM': (20330, 1),
#     u'Jobs': (44385, 1),
#     u'massive Tax Cuts': (52994, 1),
#     u'the same FISA law': (55832, 1),
#     u'skies': (13861, 1),
#     u'most heartfelt prayers': (17784, 1),
#     u'female unemployment': (107824, 1),
#     u'numerous forced retractions': (58810, 1),
#     u'a mess': (45596, 1),
#     u'a big step': (78492, 2),
#     u'God Bless': (44334, 1),
#     u'London': (60158, 2),
#     u't': (41310, 2),
#     u'monumental achievement': (23750, 1),
#     u'enthusiastic Roy Moore fans': (27828, 1),
#     u'empty arena': (48544, 1),
#     u'Sneaky Dianne Feinstein': (45480, 1),
#     u'a complete travesty': (71682, 1),
#     u'picture': (24272, 1),
#     u'modern times': (50480, 1),
#     u'The people': (153882, 2),
#     u'the White House': (116954, 2),
#     u'any other Administration': (62696, 1),
#     u'CNN THE MOST TRUSTED NAME IN NEWS Everyone': (74954, 1),
#     u'Met': (18464, 1),
#     u'a job': (20106, 1),
#     u'power': (42742, 1),
#     u'the military': (33814, 1),
#     u'Tiger Woods': (31212, 1),
#     u't exist': (50700, 1),
#     u'testimony': (22740, 1),
#     u'a big day': (49194, 1),
#     u'shoplifting': (77081, 1),
#     u'the father': (154162, 1),
#     u'the U S CNN International': (68024, 1),
#     u'Regs': (22929, 1),
#     u'campaign contributions': (47332, 1),
#     u'Federal Regulations Today': (52208, 1),
#     u'the Dems': (139632, 2),
#     u'ribbon NO': (60158, 1),
#     u'the truth': (126834, 2),
#     u'aren': (20873, 1),
#     u'Man Person': (87834, 1),
#     u'a years': (52044, 1),
#     u'troubled country Never': (73220, 1),
#     u'more Republicans': (114176, 2),
#     u'real knowledge': (45072, 1),
#     u'the great wealth': (52070, 1),
#     u'infrastructure plan': (46834, 1),
#     u'favorite President': (116594, 2),
#     u'the workplace': (52588, 1),
#     u'many good friends': (17132, 1),
#     u'destinies': (8744, 1),
#     u'state officials': (28030, 1),
#     u'highest privilege': (26320, 1),
#     u'countless American factories': (25708, 1),
#     u'House': (45684, 2),
#     u'Iran s people': (47064, 1),
#     u'the Fake News convince': (46442, 1),
#     u'no goal': (33698, 1),
#     u'bad LaVar': (66366, 1),
#     u'beliefs': (48641, 1),
#     u'a joke foxandfriends': (58810, 1),
#     u'more places': (17488, 1),
#     u'USA': (21731, 1),
#     u'Obama border': (71682, 1),
#     u'the previous Administrations pick Financial Institutions': (30432, 1),
#     u'The Tax Cuts': (36424, 1),
#     u'these great Republicans': (56820, 1),
#     u'great battle cry': (27722, 1),
#     u'the lead': (36424, 1),
#     u'politics': (39627, 1),
#     u'HEROES': (54597, 2),
#     u'Veterans': (54020, 2),
#     u'the deadly scourge': (27562, 1),
#     u'DACA': (85147, 2),
#     u'MAGNIFICENT Capitol': (29494, 1),
#     u't let': (42004, 1),
#     u'Wow Matt Lauer': (52588, 1),
#     u'dollars millions': (25708, 1),
#     u'Great': (47531, 1),
#     u'the Middle East': (135298, 2),
#     u'tolerate terrorism': (67732, 1),
#     u'Country': (354444, 2),
#     u'the months': (52070, 1),
#     u'the Phony Hillary Clinton investigation': (72350, 1),
#     u'CNN': (133652, 2),
#     u'right Roy': (30470, 1),
#     u'beneficial commerce': (22414, 1),
#     u'FoxNews FBI s Andrew McCabe': (59508, 1),
#     u'wife': (29754, 1),
#     u'America PearlHarborRemembranceDay': (44334, 1),
#     u'defamatory stories': (61744, 1),
#     u'the White House Drumstick': (29700, 1),
#     u'many different dreams': (22896, 1),
#     u'Illegal Immigration Bad': (43180, 1),
#     u'the right thing': (55832, 1),
#     u'Marine Helicopter Squadron One HMX': (36760, 1),
#     u'the length': (62696, 1),
#     u'talks': (42198, 2),
#     u'Arizona quit race': (33064, 1),
#     u'an FBI witness': (47648, 1),
#     u'Big win': (46448, 1),
#     u'ObamaCare premiums': (37848, 1),
#     u'AMERICAN PROSPERITY': (25848, 1),
#     u'historic things': (38070, 1),
#     u'purposeful mistake yesterday': (47714, 1),
#     u'the hair Just think': (66366, 1),
#     u'Quantico Virginia': (36760, 1),
#     u'this seat': (49878, 1),
#     u'Florida years': (54206, 2),
#     u'the history': (35680, 1),
#     u'dollar trade surplus': (56352, 1),
#     u'penalties': (45858, 2),
#     u'streets': (19891, 1),
#     u'past': (26294, 1),
#     u'the Obama Administration': (60158, 1),
#     u'North Korea missile launch': (47794, 1),
#     u'China Ungrateful fool': (78094, 1),
#     u'the nomination': (50700, 1),
#     u'Marshawn Lynch': (75212, 1),
#     u'the MASSIVE TAX CUT amp Reform Bill': (36200, 1),
#     u'witnesses': (12949, 1),
#     u'version': (33183, 1),
#     u'disrespect Next time NFL': (75212, 1),
#     u'Russians': (22798, 1),
#     u'Charles McCullough': (41746, 1),
#     u'The Wall Street Journal': (45334, 1),
#     u'the Philippines': (17132, 1),
#     u'this week': (78528, 2),
#     u'Crooked Hillary Emails Emails': (41746, 1),
#     u'hours': (72174, 2),
#     u'office begging': (47332, 1),
#     u'dangerous Southern Border': (85484, 1),
#     u'all First Responders': (28030, 1),
#     u'the Republicans': (227008, 2),
#     u'Individual Mandate': (57372, 1),
#     u'American History All American hearts': (25898, 1),
#     u'Border': (39974, 1),
#     u'TOUGHER AND SMARTER': (42166, 1),
#     u'Things': (28859, 1),
#     u'a News Conference': (64124, 1),
#     u'tomorrow morning': (26064, 1),
#     u'PEARL HARBOR': (44334, 1),
#     u'Europe': (13861, 1),
#     u'TRILLIONS OF DOLLARS': (131858, 1),
#     u'a big step backwards Wall': (43462, 1),
#     u'Brian Ross': (178724, 2),
#     u'Big protests': (60824, 1),
#     u'authorization': (45767, 2),
#     u'defenseless worshipers': (67732, 1),
#     u'Trump Very disloyal': (47332, 1),
#     u'little margin': (39640, 1),
#     u'entire industries': (25708, 1),
#     u'time ObamaCare': (41312, 1),
#     u'great news': (38370, 1),
#     u'Prime Minister Erna Solberg': (19140, 1),
#     u'a major photo shoot': (87834, 1),
#     u'House seats': (38768, 1),
#     u'the right thing Doug Jones': (43180, 1),
#     u'highest level': (19212, 1),
#     u'history': (43909, 2),
#     u'the Border Bad': (53604, 1),
#     u'different reasons': (38414, 1),
#     u'no C R s': (95062, 1),
#     u'another big day': (1096, 1),
#     u'a wonderful American Tradition': (29700, 1),
#     u'numbers': (30971, 2),
#     u'court': (35841, 1),
#     u'the U S Military building': (31684, 1),
#     u'the NFL s Oakland Raiders': (75212, 1),
#     u'a Schumer Pelosi puppet': (53604, 1),
#     u'many other gangs Hundreds': (39782, 1),
#     u'dangerous Southern Border Dems': (62856, 1),
#     u'a VERY dishonest': (100684, 1),
#     u'Don': (23221, 1),
#     u'the purchase': (21038, 1),
#     u'Lottery amp Chain USA': (59028, 1),
#     u'Pass': (21002, 1),
#     u'low approval rating foxandfriends': (46368, 1),
#     u'ALL Massive Tax Cuts end': (57372, 1),
#     u'the Number One State': (56256, 1),
#     u'the border': (44478, 1),
#     u'Mexico': (180510, 2),
#     u'this time VERIFY CLAIMS IN DOSSIER OF RUSSIA TRUMP COLLUSION FBI TAINTED': (71256,
#      1),
#     u'the stars': (52110, 1),
#     u'a point': (58718, 1),
#     u'Democrats': (144586, 2),
#     u'many more VICTORIES': (36200, 1),
#     u'a stain': (61744, 1),
#     u'Wells Fargo Bank': (45858, 1),
#     u'trade': (29359, 1),
#     u'the Code': (52208, 1),
#     u'All signs': (50688, 1),
#     u'existence': (33866, 1),
#     u'the act': (34548, 1),
#     u'A Tax Cuts': (52070, 1),
#     u'the Year': (87834, 1),
#     u'top rate': (33056, 1),
#     u'the launch': (33814, 1),
#     u'peanuts': (58255, 2),
#     u'service ArmyNavyGame USA': (21984, 1),
#     u'ally': (9570, 1),
#     u'an interview': (87834, 1),
#     u'someone': (23666, 1),
#     u'leakin James Comey': (72350, 1),
#     u'communities': (19891, 1),
#     u'ICEgov HSI agents': (27644, 1),
#     u'recent years': (28822, 2),
#     u'Amendment': (53299, 2),
#     u'economic decline Thank': (38632, 1),
#     u'a big fan': (60158, 1),
#     u'the help': (34548, 1),
#     u'friendship': (9485, 1),
#     u'economic news': (53184, 1),
#     u'everyone': (124771, 2),
#     u'LaVar shoplifting': (78094, 1),
#     u'police': (17043, 1),
#     u'Sanctuaries': (35354, 1),
#     u'NBC amp Comcast': (52588, 1),
#     u'the situation': (17784, 1),
#     u'diverse cultures': (22896, 1),
#     u'Phil Griffin': (54206, 2),
#     u'any collusion': (76312, 1),
#     u'a generation chance Obstructionist Dems': (35680, 1),
#     u'Flag': (35856, 2),
#     u'safety': (73854, 2),
#     u'the beautiful Blue Ridge Mountains': (29700, 1),
#     u'both Iraq': (63668, 2),
#     u'The outside world': (68024, 1),
#     u'the SENATE MUST PASS TAX CUTS': (25848, 1),
#     u'illegal way': (45480, 1),
#     u'a NO': (33064, 1),
#     u'ERO officers': (27644, 1),
#     u'Congress': (72429, 2),
#     u'People': (37592, 1),
#     u'The unemployment rate': (108546, 3),
#     u'year low': (36182, 1),
#     u'w': (16528, 1),
#     u'illegal immigration': (99970, 2),
#     u'called bipartisan DACA deal': (43462, 1),
#     u'ABC News': (178724, 2),
#     u'no DACA': (70416, 1),
#     u'the Indo Pacific': (18970, 1),
#     u'America Together': (25084, 1),
#     u'the Trump Administration': (45456, 1),
#     u'TRADE': (16950, 1),
#     u'the WALL Jones': (43180, 1),
#     u'the players': (30650, 1),
#     u'accurate polls': (31472, 1),
#     u'low ratings Joe Scarborough': (54206, 2),
#     u'wonderful': (22536, 1),
#     u'people Companies': (73254, 1),
#     u'the nations': (18970, 1),
#     u'the TaxCutsandJobsAct': (32432, 1),
#     u'PATRIOTISM PROSPERITY AND PRIDE': (36800, 1),
#     u'SUCCESS': (25344, 1),
#     u'The Consumer Confidence Index': (19212, 1),
#     u'Companies': (51088, 2),
#     u'Illegal Immigrants': (85484, 1),
#     u'part': (20656, 1),
#     u'the WORLD': (68024, 1),
#     u'new Record High yesterday': (31684, 1),
#     u'Problem': (20973, 1),
#     u'Long hours': (20106, 1),
#     u'television Bad Reporting': (68036, 1),
#     u'the United States Post Office': (55304, 1),
#     u'Military Crime Borders': (57372, 1),
#     u'deep State authorities': (41746, 1),
#     u'this room today': (22414, 1),
#     u'God': (48641, 1),
#     u'illegal immigrants': (137008, 2),
#     u'friends supporters enemies haters': (79396, 1),
#     u'orders': (14015, 1),
#     u'Tax Cuts': (128852, 2),
#     u'VOTE ROY MOORE': (43180, 1),
#     u'the American Public': (74954, 1),
#     u'dishonest report': (55826, 1),
#     u'the Trump Campaign': (105804, 2),
#     u'the public': (76486, 2),
#     u'bad acts': (45858, 1),
#     u'a lawyer': (75184, 1),
#     u'reach': (16849, 1),
#     u'Chief': (18380, 1),
#     u'plan': (27577, 2),
#     u'the COLDEST New Year': (131858, 1),
#     u'USNavy': (10992, 1),
#     u'biggest loser': (102780, 1),
#     u'open Indo Pacific': (22896, 1),
#     u'Egypt': (76032, 2),
#     u'INDEPENDENT nations': (17488, 1),
#     u'the WALL': (42166, 1),
#     ...},
#    {u'amp inspire Americans': (122058, 1),
#     u'votes': (275413, 2),
#     u'The American public': (202054, 1),
#     u'MUCH': (118765, 1),
#     u'great country': (412136, 1),
#     u'SenateMajLdr Mitch McConnell': (142926, 1),
#     u'MAKING AMERICA GREAT AGAIN MAGA': (204150, 1),
#     u'a shame': (233314, 1),
#     u'President Trump': (224186, 1),
#     u'SenateMajLdr McConnell': (126968, 1),
#     u'a phony photo': (154438, 1),
#     u'Remember Republicans': (176416, 1),
#     u'Firefighters paramedics': (217228, 1),
#     u'The Chinese Envoy': (152904, 1),
#     u'no clue': (271816, 1),
#     u'Military': (100174, 1),
#     u'OUR WORKERS': (97664, 1),
#     u'National Anthem Weak': (202054, 1),
#     u'Economists': (60513, 1),
#     u'companies': (410567, 2),
#     u'TANKED': (2182, 1),
#     u'jamiejmcintyre': (38520, 1),
#     u'South Korea': (125304, 1),
#     u'leaders': (77986, 1),
#     u'The Fake News': (280598, 1),
#     u'President Recep Tayyip Erdogan': (139528, 1),
#     u'the Presidential Election': (200010, 1),
#     u'an off location': (250366, 1),
#     u'the mess': (139528, 1),
#     u'the Tax Cuts': (232240, 1),
#     u'Amazon': (118765, 1),
#     u'a big beautiful Christmas': (109764, 1),
#     u'safety DACA': (184194, 1),
#     u'the Senate': (1149598, 2),
#     u'no NBA contract': (321944, 1),
#     u'Great Military': (207774, 1),
#     u'much Fake News Check': (203570, 1),
#     u'this moment': (154242, 1),
#     u'another shot': (246124, 1),
#     u'Shoplifting': (135939, 1),
#     u'provision becomes simpler': (168086, 1),
#     u'the lives': (245414, 1),
#     u'employees': (119914, 2),
#     u'week extension': (126968, 1),
#     u'reports': (195754, 1),
#     u'the Staff': (87048, 1),
#     u'NOT': (288004, 2),
#     u'a fraud': (296086, 1),
#     u'campaign': (210237, 2),
#     u'fight fight fight': (157666, 1),
#     u'real economics': (146650, 1),
#     u'National Anthem Great': (314676, 1),
#     u'Healthy New Year': (317990, 1),
#     u'the interests': (99030, 1),
#     u'all Countries': (168042, 1),
#     u'political career anyway': (141582, 1),
#     u'MORE TO COME': (300176, 1),
#     u'a Great Wall': (245414, 1),
#     u'any other President': (202462, 1),
#     u'the phony Democrat excuse': (310038, 1),
#     u'that day': (163282, 1),
#     u'best reading': (82070, 1),
#     u'a day Wrong': (277536, 1),
#     u'the day Trump': (214050, 2),
#     u'rights': (138901, 1),
#     u'the bonds': (87508, 1),
#     u'poor decision': (198334, 1),
#     u'LAST thing': (151788, 1),
#     u'many outlets': (296086, 1),
#     u'end': (86380, 1),
#     u'Numbers Lowest Unemployment': (254396, 1),
#     u'The Wall': (409624, 2),
#     u'FAKE NEWS WaPo': (154438, 1),
#     u'all Americans': (463858, 2),
#     u'the WhiteHouse Bahrain': (94828, 1),
#     u'the Tax Cut Bill': (301424, 2),
#     u'mess': (142493, 1),
#     u'Grand Staircase Escalante': (135208, 1),
#     u'other countries': (408302, 1),
#     u'West Palm Beach Fire amp Rescue': (217228, 1),
#     u'a day': (228092, 1),
#     u'weak borders': (219470, 1),
#     u'Donald Trump Big stuff Deep State Give': (147450, 1),
#     u'order': (485010, 2),
#     u'operations': (98531, 1),
#     u'big companies': (190624, 1),
#     u'great support': (168086, 1),
#     u'office': (461729, 2),
#     u'the Pacific': (127532, 1),
#     u'FLOTUS Melania': (122402, 1),
#     u'The massive TRADE deficits': (168042, 1),
#     u'ECONOMY': (60513, 1),
#     u'the next level': (220224, 1),
#     u'Excellent preliminary meeting': (126968, 1),
#     u'humanity Whatever': (309596, 1),
#     u'The Christmas Story': (309596, 1),
#     u'the election': (550278, 2),
#     u'stalemate': (173855, 1),
#     u'the Fake Mainstream Media': (172760, 1),
#     u'a wonderful relationship': (277600, 1),
#     u'many great American workers': (197062, 1),
#     u'many beautiful JOBS': (139796, 1),
#     u'the election Russia Russia Russia': (310038, 1),
#     u'victory': (75894, 1),
#     u'side': (160737, 2),
#     u'regs rules': (114882, 1),
#     u'SecretaryAcosta USDOL': (131274, 1),
#     u'big amp': (139300, 1),
#     u'ASEAN50': (48188, 1),
#     u'Wow': (120149, 1),
#     u'crimes': (130478, 1),
#     u'Mainstream Meadia': (240298, 1),
#     u'the pleasure': (105170, 1),
#     u'Government Funding Bill': (219470, 1),
#     u'no big deal': (550784, 1),
#     u'a new Executive Order': (164302, 1),
#     u'a Pelosi Schumer Puppet Roy Moore': (162772, 1),
#     u'the fact': (648644, 2),
#     u'The Russian Collusion Hoax': (222752, 1),
#     u'Tax Cut Bill': (220416, 1),
#     u'Points USA Sadly': (172760, 1),
#     u'months Lowest': (412136, 1),
#     u'Circuit': (108152, 1),
#     u'THANK YOU Pensacola Florida': (157666, 1),
#     u'Many people': (229894, 1),
#     u'Reform Fiat Chrysler': (146814, 1),
#     u'Clinton': (82158, 1),
#     u'Chain': (83927, 1),
#     u'size Immediate expensing': (139796, 1),
#     u'days': (209472, 2),
#     u'this year': (347112, 2),
#     u'an incredible victory': (81782, 1),
#     u'every new supersonic jet': (122058, 1),
#     u'The USA': (216686, 1),
#     u'a place': (105170, 1),
#     u'service': (140470, 2),
#     u'Republicans Democrats': (207774, 1),
#     u'massive negative Trump coverage amp Russia hoax': (196344, 1),
#     u'big deal': (593822, 2),
#     u'Haiti': (138800, 1),
#     u'the Southern Border': (529626, 2),
#     u'the WrightBrothers': (122058, 1),
#     u'a big win': (207774, 1),
#     u'Beautiful': (206068, 1),
#     u'The voters': (231140, 1),
#     u'anemic polls': (141582, 1),
#     u'preparation': (135522, 1),
#     u'See': (103887, 1),
#     u'a mistake': (139528, 1),
#     u'appropriate civic community': (218444, 1),
#     u'the year': (248314, 2),
#     u'The Mainstream Media': (296214, 1),
#     u'mine': (49515, 1),
#     u'ratings way': (314676, 1),
#     u'the Failing nytimes': (277536, 1),
#     u'strength': (60351, 1),
#     u'unpopular Indiv Mandate': (155706, 1),
#     u'big way Congratulations': (353202, 1),
#     u'a massive tax cut': (264006, 2),
#     u'Jones': (97402, 1),
#     u'Fake News': (774014, 2),
#     u'such horrible conditions Russia': (152904, 1),
#     u'the top executives': (203570, 1),
#     u'past Admins': (271816, 1),
#     u'no collusion everybody': (239096, 1),
#     u'Jerusalem': (135522, 1),
#     u'the story': (309596, 1),
#     u'hard dream': (139300, 1),
#     u'great Supreme Court Justice RECORD CUT IN REGS': (415210, 1),
#     u'Election': (370680, 2),
#     u'the man': (242708, 1),
#     u'a little bit': (408302, 1),
#     u'many other things': (174546, 1),
#     u'the only way': (631806, 2),
#     u'law enforcement families God Bless': (145190, 1),
#     u'the Justice Department': (229894, 1),
#     u'meetings': (161393, 2),
#     u'profitability': (112093, 1),
#     u'Country Senate Republicans': (174546, 1),
#     u'foreign intelligence collection': (254064, 1),
#     u'solutions': (63484, 1),
#     u'a great game today USArmy': (107178, 1),
#     u'ridiculous Lottery System': (284212, 1),
#     u'amp retraction': (154438, 1),
#     u'Iranian govt': (277802, 1),
#     u'many more companies': (239828, 2),
#     u'Republicans': (595706, 2),
#     u'the economy Tax Cut': (224186, 1),
#     u'foreign surveillance': (121120, 1),
#     u'the uniform': (163282, 1),
#     u'the C R TODAY': (178256, 1),
#     u'big payments': (223590, 1),
# ...
#     u'Reform Bill Terrible Individual Mandate ObamaCare Repealed Goes': (281874,
#      1),
#     u'a nation': (139300, 1),
#     u'Border Security': (313222, 2),
#     u'David Bossie': (221120, 1),
#     u'first responders': (217228, 1),
#     u'A big contingent': (120698, 1),
#     u'Seven': (106936, 1),
#     u'tough rivers': (187100, 1),
#     u'amp Democrats': (112874, 1),
#     u'bogus Clinton Campaign DNC': (238956, 1),
#     u'ALL YEAR LONG': (228092, 1),
#     u'The Bill': (164196, 1),
#     u'Court': (65832, 1),
#     u'economic security IS': (120204, 2),
#     u'Shutdown politics': (284986, 1),
#     u'highest Stock Market EVER Military': (415210, 1),
#     u'voices': (77121, 1),
#     u'a NATION': (204150, 1),
#     u'the vile criminal cartel MS13': (152386, 1),
#     u'The enactment': (121026, 1),
#     u'next trip': (271878, 1),
#     u'The fact': (184454, 1),
#     u's friends': (127532, 1),
#     u'the past amp dedicate': (132158, 1),
#     u'a Trumper': (170696, 1),
#     u'the people': (566650, 2),
#     u'last legs': (131664, 1),
#     u'year reviews': (172760, 1),
#     u'Amazon richer': (237530, 1),
#     u'no task': (139300, 1),
#     u'Rex Tillerson': (176374, 1),
#     u'RICK SACCONE': (169206, 1),
#     u'This GREAT AMERICAN SPIRIT': (122058, 1),
#     u'a comprehensive overhaul complete': (121026, 1),
#     u'Don King': (252800, 1),
#     u'pages': (177808, 2),
#     u'CUT TAXES': (97664, 1),
#     u'the WhiteHouse': (101010, 1),
#     u'Merit': (122707, 1),
#     u'Good Republican candidates': (170696, 1),
#     u'a total flunky': (177986, 1),
#     u'rating': (98172, 1),
#     u'WE': (148107, 1),
#     u'next generation': (122058, 1),
#     u'the Rep House': (155706, 1),
#     u'the Wall': (677068, 2),
#     u'representatives': (108614, 1),
#     u'Fake Polls': (280598, 1),
#     u'Time Magazine': (333074, 1),
#     u'crime': (193464, 2),
#     u'the Fake News': (609526, 2),
#     u'the first place': (139528, 1),
#     u'Crooked Hillary AFTER': (229894, 1),
#     u'a lifetime opportunity': (105332, 1),
#     u'The White House': (281874, 1),
#     u'full term': (300176, 1),
#     u'means nothing': (240606, 1),
#     u'fabricated stories': (295772, 1),
#     u'MERRY CHRISTMAS': (228092, 1),
#     u'the damages': (249514, 1),
#     u'Tax cut money': (235464, 1),
#     u'miles': (64290, 1),
#     u'a perfect place': (245048, 1),
#     u'last time': (130560, 1),
#     u'vision': (52585, 1),
#     u'the Border': (347710, 1),
#     u'solemn tribute': (132158, 1),
#     u'Wishbone': (75318, 1),
#     u'big week': (174546, 1),
#     u'a disaster': (387008, 2),
#     u'The Pelosi Schumer Puppet Jones': (151788, 1),
#     u'the transition': (233314, 1),
#     u'no challenge': (139300, 1),
#     u'squandering': (138901, 1),
#     u'the birth': (309596, 1),
#     u'an unexpected new source': (190624, 1),
#     u'highest civilian honor': (148814, 1),
#     u'human rights violations': (216686, 1),
#     u'The Kate Steinle killer': (260956, 1),
#     u'jobs': (429342, 2),
#     u'The Stock Market': (202462, 1),
#     u'Fake reporting': (87048, 1),
#     u'a double standard': (289408, 1),
#     u'a SHUTDOWN': (178256, 1),
#     u'a shutdown': (192554, 1),
#     u'wonderful First Responders': (166268, 1),
#     u'this Crooked Hillary pile': (238956, 1),
#     u'big unnecessary regulation cuts': (177018, 1),
#     u'tour': (84021, 1),
#     u'last night': (708840, 2),
#     u'California s wildfires': (134028, 1),
#     u'dishonest corrupt': (307670, 1),
#     u'duty': (122707, 1),
#     u'a good thing': (317406, 1),
#     u'extraordinary museums': (132158, 1),
#     u'The write': (246124, 1),
#     u'Norway': (50505, 1),
#     u'biased media': (356912, 1),
#     u'the historic milestones': (412136, 1),
#     u'this information NOW FoxNews': (147450, 1),
#     u'the Fake Book': (296214, 1),
#     u'the dumbest man': (277536, 1),
#     u'cities': (125611, 1),
#     u'drug addiction': (118600, 1),
#     u'Packed house': (154438, 1),
#     u'a Lago': (185464, 1),
#     u'Vets': (207605, 1),
#     u'Melania': (113070, 1),
#     u'the contract': (197564, 2),
#     u'borders': (96062, 1),
#     u'President Xi': (125304, 1),
#     u'incredible work': (134028, 1),
#     u'the biggest corporate rate cut': (146650, 1),
#     u'the dawn': (154242, 1),
#     u'overdose': (59300, 1),
#     u'country trillions': (114882, 1),
#     u'the horrible Chain Migration': (284212, 1),
#     u'Commander': (78203, 1),
#     u'final vote': (281874, 1),
#     u'policies': (198104, 2),
#     u'evening': (61201, 1),
#     u'Crime WEAK': (206258, 1),
#     u'Israel': (135522, 1),
#     u'author': (148107, 1),
#     u'U S Michigan': (4364, 1),
#     u's': (248602, 2),
#     u'surveillance': (73725, 1),
#     u'speech': (89981, 1),
#     u'finest embassy': (250366, 1),
#     u'the number': (244984, 1),
#     u'M Clinton Puppet': (199354, 1),
#     u'The good news': (300176, 1),
#     u'a huge pro growth stimulus': (146650, 1),
#     u'Toyota': (89943, 1),
#     u'the national monuments designations': (135208, 1),
#     u'great political victory': (125304, 1),
#     u'The Dow': (200010, 1),
#     u'the Roosevelt Room': (114882, 1),
#     u'much look': (125304, 1),
#     u'North Korea Syria Ukraine terrorism': (317406, 1),
#     u'beautiful list': (172760, 1),
#     u'the flow': (118600, 1),
#     u'nothing happens': (289408, 1),
#     u'The Tax Cut Reform Bill': (222828, 1),
#     u'money': (324968, 2),
#     u'SOVEREIGN': (40094, 1),
#     u'actions': (116657, 1),
#     u'much loss': (205668, 1),
#     u'TAX REFORM': (97286, 1),
#     u'Jobs': (207605, 1),
#     u'massive Tax Cuts': (194804, 1),
#     u'the same FISA law': (254064, 1),
#     u'skies': (63766, 1),
#     u'most heartfelt prayers': (85966, 1),
#     u'female unemployment': (412136, 1),
#     u'numerous forced retractions': (240298, 1),
#     u'a mess': (164316, 1),
#     u'a big step': (320406, 2),
#     u'God Bless': (163282, 1),
#     u'London': (250366, 2),
#     u't': (176976, 2),
#     u'monumental achievement': (112102, 1),
#     u'enthusiastic Roy Moore fans': (120698, 1),
#     u'empty arena': (179962, 1),
#     u'Sneaky Dianne Feinstein': (184454, 1),
#     u'a complete travesty': (260956, 1),
#     u'picture': (89981, 1),
#     u'modern times': (224186, 1),
#     u'The people': (625582, 2),
#     u'the White House': (506116, 2),
#     u'any other Administration': (300176, 1),
#     u'CNN THE MOST TRUSTED NAME IN NEWS Everyone': (296086, 1),
#     u'Met': (108614, 1),
#     u'a job': (87048, 1),
#     u'power': (142493, 1),
#     u'the military': (152904, 1),
#     u'Tiger Woods': (185464, 1),
#     u't exist': (194776, 1),
#     u'testimony': (92227, 1),
#     u'a big day': (235464, 1),
#     u'shoplifting': (275392, 1),
#     u'the father': (550784, 1),
#     u'the U S CNN International': (229834, 1),
#     u'Regs': (99072, 1),
#     u'campaign contributions': (177986, 1),
#     u'Federal Regulations Today': (177808, 1),
#     u'the Dems': (619856, 2),
#     u'ribbon NO': (250366, 1),
#     u'the truth': (470132, 2),
#     u'aren': (64919, 1),
#     u'Man Person': (333074, 1),
#     u'a years': (231140, 1),
#     u'troubled country Never': (277600, 1),
#     u'more Republicans': (473908, 2),
#     u'real knowledge': (221120, 1),
#     u'the great wealth': (212472, 1),
#     u'infrastructure plan': (213872, 1),
#     u'favorite President': (449252, 2),
#     u'the workplace': (203570, 1),
#     u'many good friends': (96376, 1),
#     u'destinies': (40094, 1),
#     u'state officials': (134028, 1),
#     u'highest privilege': (128580, 1),
#     u'countless American factories': (114882, 1),
#     u'House': (200646, 2),
#     u'Iran s people': (155972, 1),
#     u'the Fake News convince': (222828, 1),
#     u'no goal': (139300, 1),
#     u'bad LaVar': (252800, 1),
#     u'beliefs': (154798, 1),
#     u'a joke foxandfriends': (240298, 1),
#     u'more places': (80188, 1),
#     u'USA': (83927, 1),
#     u'Obama border': (260956, 1),
#     u'the previous Administrations pick Financial Institutions': (143874, 1),
#     u'The Tax Cuts': (158310, 1),
#     u'these great Republicans': (256472, 1),
#     u'great battle cry': (127532, 1),
#     u'the lead': (158310, 1),
#     u'politics': (158703, 1),
#     u'HEROES': (226059, 2),
#     u'Veterans': (225804, 2),
#     u'the deadly scourge': (118600, 1),
#     u'DACA': (362831, 2),
#     u'MAGNIFICENT Capitol': (135208, 1),
#     u't let': (178256, 1),
#     u'Wow Matt Lauer': (203570, 1),
#     u'dollars millions': (114882, 1),
#     u'Great': (173855, 1),
#     u'the Middle East': (598448, 2),
#     u'tolerate terrorism': (291294, 1),
#     u'Country': (1459121, 2),
#     u'the months': (212472, 1),
#     u'the Phony Hillary Clinton investigation': (242708, 1),
#     u'CNN': (500298, 2),
#     u'right Roy': (151266, 1),
#     u'beneficial commerce': (99030, 1),
#     u'FoxNews FBI s Andrew McCabe': (199354, 1),
#     u'wife': (99677, 1),
#     u'America PearlHarborRemembranceDay': (163282, 1),
#     u'defamatory stories': (240606, 1),
#     u'the White House Drumstick': (150636, 1),
#     u'many different dreams': (105170, 1),
#     u'Illegal Immigration Bad': (162772, 1),
#     u'the right thing': (254064, 1),
#     u'Marine Helicopter Squadron One HMX': (156406, 1),
#     u'the length': (300176, 1),
#     u'talks': (204108, 2),
#     u'Arizona quit race': (141582, 1),
#     u'an FBI witness': (147450, 1),
#     u'Big win': (207774, 1),
#     u'ObamaCare premiums': (180750, 1),
#     u'AMERICAN PROSPERITY': (105332, 1),
#     u'historic things': (172760, 1),
#     u'purposeful mistake yesterday': (185556, 1),
#     u'the hair Just think': (252800, 1),
#     u'Quantico Virginia': (156406, 1),
#     u'this seat': (246124, 1),
#     u'Florida years': (197564, 2),
#     u'the history': (164196, 1),
#     u'dollar trade surplus': (222524, 1),
#     u'penalties': (198144, 2),
#     u'streets': (76193, 1),
#     u'past': (101785, 1),
#     u'the Obama Administration': (250366, 1),
#     u'North Korea missile launch': (192554, 1),
#     u'China Ungrateful fool': (321944, 1),
#     u'the nomination': (194776, 1),
#     u'Marshawn Lynch': (314676, 1),
#     u'the MASSIVE TAX CUT amp Reform Bill': (177408, 1),
#     u'witnesses': (62267, 1),
#     u'version': (126400, 1),
#     u'disrespect Next time NFL': (314676, 1),
#     u'Russians': (82158, 1),
#     u'Charles McCullough': (129838, 1),
#     u'The Wall Street Journal': (192324, 1),
#     u'the Philippines': (96376, 1),
#     u'this week': (322388, 2),
#     u'Crooked Hillary Emails Emails': (129838, 1),
#     u'hours': (286654, 2),
#     u'office begging': (177986, 1),
#     u'dangerous Southern Border': (284986, 1),
#     u'all First Responders': (134028, 1),
#     u'the Republicans': (996024, 2),
#     u'Individual Mandate': (254396, 1),
#     u'American History All American hearts': (124534, 1),
#     u'Border': (152351, 1),
#     u'TOUGHER AND SMARTER': (205668, 1),
#     u'Things': (127436, 1),
#     u'a News Conference': (281874, 1),
#     u'tomorrow morning': (122402, 1),
#     u'PEARL HARBOR': (163282, 1),
#     u'Europe': (63766, 1),
#     u'TRILLIONS OF DOLLARS': (408302, 1),
#     u'a big step backwards Wall': (167854, 1),
#     u'Brian Ross': (650950, 2),
#     u'Big protests': (216686, 1),
#     u'authorization': (191394, 2),
#     u'defenseless worshipers': (291294, 1),
#     u'Trump Very disloyal': (177986, 1),
#     u'little margin': (151788, 1),
#     u'entire industries': (114882, 1),
#     u'time ObamaCare': (220416, 1),
#     u'great news': (146814, 1),
#     u'Prime Minister Erna Solberg': (101010, 1),
#     u'a major photo shoot': (333074, 1),
#     u'House seats': (164802, 1),
#     u'the right thing Doug Jones': (162772, 1),
#     u'highest level': (82070, 1),
#     u'history': (202643, 2),
#     u'the Border Bad': (206258, 1),
#     u'different reasons': (176416, 1),
#     u'no C R s': (347710, 1),
#     u'another big day': (4364, 1),
#     u'a wonderful American Tradition': (150636, 1),
#     u'numbers': (140913, 2),
#     u'court': (130478, 1),
#     u'the U S Military building': (156774, 1),
#     u'the NFL s Oakland Raiders': (314676, 1),
#     u'a Schumer Pelosi puppet': (206258, 1),
#     u'many other gangs Hundreds': (152386, 1),
#     u'dangerous Southern Border Dems': (232240, 1),
#     u'a VERY dishonest': (391508, 1),
#     u'Don': (111414, 1),
#     u'the purchase': (94828, 1),
#     u'Lottery amp Chain USA': (245414, 1),
#     u'Pass': (89128, 1),
#     u'low approval rating foxandfriends': (196344, 1),
#     u'ALL Massive Tax Cuts end': (254396, 1),
#     u'the Number One State': (175354, 1),
#     u'the border': (188710, 1),
#     u'Mexico': (752438, 2),
#     u'this time VERIFY CLAIMS IN DOSSIER OF RUSSIA TRUMP COLLUSION FBI TAINTED': (238956,
#      1),
#     u'the stars': (204150, 1),
#     u'a point': (271816, 1),
#     u'Democrats': (559753, 2),
#     u'many more VICTORIES': (177408, 1),
#     u'a stain': (240606, 1),
#     u'Wells Fargo Bank': (198144, 1),
#     u'trade': (135908, 1),
#     u'the Code': (177808, 1),
#     u'All signs': (261518, 1),
#     u'existence': (145647, 1),
#     u'the act': (144820, 1),
#     u'A Tax Cuts': (212472, 1),
#     u'the Year': (333074, 1),
#     u'top rate': (155706, 1),
#     u'the launch': (152904, 1),
#     u'peanuts': (236445, 2),
#     u'service ArmyNavyGame USA': (107178, 1),
#     u'ally': (50505, 1),
#     u'an interview': (333074, 1),
#     u'someone': (88993, 1),
#     u'leakin James Comey': (242708, 1),
#     u'communities': (76193, 1),
#     u'ICEgov HSI agents': (120504, 1),
#     u'recent years': (120204, 2),
#     u'Amendment': (200531, 2),
#     u'economic decline Thank': (177018, 1),
#     u'a big fan': (250366, 1),
#     u'the help': (144820, 1),
#     u'friendship': (43754, 1),
#     u'economic news': (222752, 1),
#     u'everyone': (598708, 2),
#     u'LaVar shoplifting': (321944, 1),
#     u'police': (72595, 1),
#     u'Sanctuaries': (125611, 1),
#     u'NBC amp Comcast': (203570, 1),
#     u'the situation': (85966, 1),
#     u'diverse cultures': (105170, 1),
#     u'Phil Griffin': (197564, 2),
#     u'any collusion': (295772, 1),
#     u'a generation chance Obstructionist Dems': (164196, 1),
#     u'Flag': (162109, 2),
#     u'safety': (309012, 2),
#     u'the beautiful Blue Ridge Mountains': (150636, 1),
#     u'both Iraq': (214050, 2),
#     u'The outside world': (229834, 1),
#     u'the SENATE MUST PASS TAX CUTS': (105332, 1),
#     u'illegal way': (184454, 1),
#     u'a NO': (141582, 1),
#     u'ERO officers': (120504, 1),
#     u'Congress': (324546, 2),
#     u'People': (124757, 1),
#     u'The unemployment rate': (393822, 3),
#     u'year low': (131274, 1),
#     u'w': (77853, 1),
#     u'illegal immigration': (412024, 2),
#     u'called bipartisan DACA deal': (167854, 1),
#     u'ABC News': (650950, 2),
#     u'no DACA': (284212, 1),
#     u'the Indo Pacific': (87508, 1),
#     u'America Together': (109764, 1),
#     u'the Trump Administration': (202462, 1),
#     u'TRADE': (84021, 1),
#     u'the WALL Jones': (162772, 1),
#     u'the players': (122164, 1),
#     u'accurate polls': (130560, 1),
#     u'low ratings Joe Scarborough': (197564, 2),
#     u'wonderful': (110560, 1),
#     u'people Companies': (353202, 1),
#     u'the nations': (87508, 1),
#     u'the TaxCutsandJobsAct': (136212, 1),
#     u'PATRIOTISM PROSPERITY AND PRIDE': (154242, 1),
#     u'SUCCESS': (130759, 1),
#     u'The Consumer Confidence Index': (82070, 1),
#     u'Companies': (242554, 2),
#     u'Illegal Immigrants': (284986, 1),
#     u'part': (110208, 1),
#     u'the WORLD': (229834, 1),
#     u'new Record High yesterday': (156774, 1),
#     u'Problem': (86493, 1),
#     u'Long hours': (87048, 1),
#     u'television Bad Reporting': (277536, 1),
#     u'the United States Post Office': (237530, 1),
#     u'Military Crime Borders': (254396, 1),
#     u'deep State authorities': (129838, 1),
#     u'this room today': (99030, 1),
#     u'God': (154798, 1),
#     u'illegal immigrants': (520696, 2),
#     u'friends supporters enemies haters': (317990, 1),
#     u'orders': (67014, 1),
#     u'Tax Cuts': (611768, 2),
#     u'VOTE ROY MOORE': (162772, 1),
#     u'the American Public': (296086, 1),
#     u'dishonest report': (215880, 1),
#     u'the Trump Campaign': (383776, 2),
#     u'the public': (342208, 2),
#     u'bad acts': (198144, 1),
#     u'a lawyer': (249514, 1),
#     u'reach': (69650, 1),
#     u'Chief': (78203, 1),
#     u'plan': (114298, 2),
#     u'the COLDEST New Year': (408302, 1),
#     u'USNavy': (53589, 1),
#     u'biggest loser': (383910, 1),
#     u'open Indo Pacific': (105170, 1),
#     u'Egypt': (351315, 2),
#     u'INDEPENDENT nations': (80188, 1),
#     u'the WALL': (205668, 1),
#     ...}))]

# %%
trump_tc_rdd_k.take(1)
# Out:
# [(1666,
#   (1666,
#    u'955806333667807232',
#    10053,
#    43524,
#    [u'thank',
#     u'general',
#     u'john',
#     u'kelli',
#     u'fantast',
#     u'staff',
#     u'white',
#     u'hous',
#     u'well',
#     u'done',
#     u'long',
#     u'hour',
#     u'fake',
#     u'make',
#     u'difficult',
#     u'alway',
#     u'great',
#     u'win',
#     u'us'],
#    [u'Thank',
#     u'General John Kelly',
#     u'a fantastic job',
#     u'the Staff',
#     u'others',
#     u'the White House',
#     u'a job',
#     u'Long hours',
#     u'Fake reporting',
#     u'job',
#     u'WIN']))]

# %%
tr = r.mapValues(get_top_6_alltime)
tr.take(1)
# Out:
# [(1666,
#   ([(u'years', (371083, 2)),
#     (u'China', (356231, 2)),
#     (u'Country', (354444, 2)),
#     (u'the U S', (331626, 2)),
#     (u'people', (323951, 2)),
#     (u'the Democrats', (302174, 2)),
#     (u'country', (293021, 2)),
#     (u'the Senate', (267012, 2)),
#     (u'the United States', (265778, 2)),
#     (u'the world', (253312, 2)),
#     (u'Crooked Hillary Clinton', (248074, 2)),
#     (u'a deal', (242424, 2)),
#     (u'the Republicans', (227008, 2)),
#     (u'life', (216215, 2)),
#     (u'America', (205955, 2)),
#     (u'Today', (201177, 2)),
#     (u'MAKE AMERICA GREAT AGAIN', (199610, 2)),
#     (u'the FBI', (198800, 2)),
#     (u'great honor', (192392, 2)),
#     (u'Fake News', (190302, 2))],
#    [(u'China', (1517409, 2)),
#     (u'Country', (1459121, 2)),
#     (u'years', (1447089, 2)),
#     (u'the U S', (1420098, 2)),
#     (u'the Democrats', (1314890, 2)),
#     (u'people', (1283102, 2)),
#     (u'country', (1237217, 2)),
#     (u'the Senate', (1149598, 2)),
#     (u'the world', (1080080, 2)),
#     (u'the Republicans', (996024, 2)),
#     (u'the United States', (990608, 2)),
#     (u'a deal', (948266, 2)),
#     (u'Crooked Hillary Clinton', (912456, 2)),
#     (u'Today', (876369, 2)),
#     (u'great honor', (860662, 2)),
#     (u'America', (833654, 2)),
#     (u'life', (810991, 2)),
#     (u'MAKE AMERICA GREAT AGAIN', (786028, 2)),
#     (u'Fake News', (774014, 2)),
#     (u'Mexico', (752438, 2))]))]

# %%
# computes the total count given total_count_rdd, tc_rdd
# tc_rdd is only the mapped version without computation
def compute_total_count(tc_rdd):
    tc_rdd_k = tc_rdd.keyBy(lambda x: x[0])
    computed_rdd = \
        tc_rdd_k.combineByKey(createCombiner, mergeValue, \
                              mergeCombiners).mapValues(get_top_6_alltime)
    return computed_rdd

# %%
test = compute_total_count(trump_total_count_rdd)

# %%
test.map(get_top_6_alltime).take(1)
# Out:
# [(1666,
#   ([(u'years', (371083, 2)),
#     (u'China', (356231, 2)),
#     (u'Country', (354444, 2)),
#     (u'the U S', (331626, 2)),
#     (u'people', (323951, 2)),
#     (u'the Democrats', (302174, 2)),
#     (u'country', (293021, 2)),
#     (u'the Senate', (267012, 2)),
#     (u'the United States', (265778, 2)),
#     (u'the world', (253312, 2)),
#     (u'Crooked Hillary Clinton', (248074, 2)),
#     (u'a deal', (242424, 2)),
#     (u'the Republicans', (227008, 2)),
#     (u'life', (216215, 2)),
#     (u'America', (205955, 2)),
#     (u'Today', (201177, 2)),
#     (u'MAKE AMERICA GREAT AGAIN', (199610, 2)),
#     (u'the FBI', (198800, 2)),
#     (u'great honor', (192392, 2)),
#     (u'Fake News', (190302, 2))],
#    [(u'China', (1517409, 2)),
#     (u'Country', (1459121, 2)),
#     (u'years', (1447089, 2)),
#     (u'the U S', (1420098, 2)),
#     (u'the Democrats', (1314890, 2)),
#     (u'people', (1283102, 2)),
#     (u'country', (1237217, 2)),
#     (u'the Senate', (1149598, 2)),
#     (u'the world', (1080080, 2)),
#     (u'the Republicans', (996024, 2)),
#     (u'the United States', (990608, 2)),
#     (u'a deal', (948266, 2)),
#     (u'Crooked Hillary Clinton', (912456, 2)),
#     (u'Today', (876369, 2)),
#     (u'great honor', (860662, 2)),
#     (u'America', (833654, 2)),
#     (u'life', (810991, 2)),
#     (u'MAKE AMERICA GREAT AGAIN', (786028, 2)),
#     (u'Fake News', (774014, 2)),
#     (u'Mexico', (752438, 2))]))]

# %%
# Out:
# [(1666,
#   (1666,
#    u'955806333667807232',
#    datetime.date(2013, 9, 9),
#    10053,
#    43524,
#    [u'thank',
#     u'general',
#     u'john',
#     u'kelli',
#     u'fantast',
#     u'staff',
#     u'white',
#     u'hous',
#     u'well',
#     u'done',
#     u'long',
#     u'hour',
#     u'fake',
#     u'make',
#     u'difficult',
#     u'alway',
#     u'great',
#     u'win',
#     u'us'],
#    datetime.date(2008, 5, 9)))]

# %%
# function to check how many times a word/phrase has been used
def occur(x):
    v  = x[1]
    dic = v[1]
    rez = []
    for k, v in dic.iteritems():
        if v[1] > 5:
            rez.append((k,v))
    return rez
r.map(occur).take(1)
# Out:
# [[(u'dossier', (146956, 6)),
#   (u'blame', (111104, 6)),
#   (u'foreign', (65185, 6)),
#   (u'cut', (977054, 6))]]

# %%
# Out:
# [(1666,
#   [(u'country', 2696338),
#    (u'the democrats', 2044864),
#    (u'fake news', 1670770),
#    (u'the world', 1587716),
#    (u'the u s', 1540800),
#    (u'china', 1517409)],
#   [(u'country', 647465),
#    (u'the democrats', 479794),
#    (u'the world', 442978),
#    (u'fake news', 430484),
#    (u'years', 371083),
#    (u'people', 361543)])]

# %%
tr_m.toDF().printSchema()
# Out:
# root
#  |-- _1: long (nullable = true)
#  |-- _2: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- _1: string (nullable = true)
#  |    |    |-- _2: long (nullable = true)
#  |-- _3: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- _1: string (nullable = true)
#  |    |    |-- _2: long (nullable = true)

# %%
alltime_df = spark.createDataFrame(tr_m, at)

# %%
at = StructType([
        StructField("uid", IntegerType(), True),    
    
        StructField("rt_word_list", ArrayType(StructType([
        StructField("word_name", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)        
        ,
    
        StructField("fav_word_list", ArrayType(StructType([
        StructField("word_name", StringType(), True),
        StructField("count", IntegerType(), False)])
        , True), True)
    ])

# %%
alltime_df = spark.createDataFrame(tr_m, at)

# %%
alltime_df.printSchema()
# Out:
# root
#  |-- uid: integer (nullable = true)
#  |-- rt_word_list: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- word_name: string (nullable = true)
#  |    |    |-- count: integer (nullable = false)
#  |-- fav_word_list: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- word_name: string (nullable = true)
#  |    |    |-- count: integer (nullable = false)

# %%
alltime_df.first()
# Out:
# Row(uid=1666, rt_word_list=[Row(word_name=u'country', count=2696338), Row(word_name=u'the democrats', count=2044864), Row(word_name=u'fake news', count=1670770), Row(word_name=u'the world', count=1587716), Row(word_name=u'the u s', count=1540800), Row(word_name=u'china', count=1517409)], fav_word_list=[Row(word_name=u'country', count=647465), Row(word_name=u'the democrats', count=479794), Row(word_name=u'the world', count=442978), Row(word_name=u'fake news', count=430484), Row(word_name=u'years', count=371083), Row(word_name=u'people', count=361543)])

# %%
save_data_frame(alltime_df, "trump_top")

# %%
# Change Type Cast

# %%
df_uncasted = spark.createDataFrame(base_nlp_rdd, schema)
df_uncasted.printSchema()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-165-25c0e2bc468e> in <module>()
# ----> 1 df_uncasted = spark.createDataFrame(base_nlp_rdd, schema)
#       2 df_uncasted.printSchema()
#
# NameError: name 'schema' is not defined

# %%
df_uncasted.first()
# Out:
# Row(city_name=None, country_name=None, creation_date=u'2010-09-24', creation_hour=11, creation_timestamp=u'2010-09-24 11:04:40+00:00', followers_count=140, friends_count=204, hashtag_count=0, media_attached=False, phrase_token=[u'n/a'], sentence_count=1, tid=362814954803433472, time_zone=u'London', tweet=u'Psalm 119:133', uid=194531988, word_token_set=[u'psalm', u'119', u'133'])

# %%
df_final = df_uncasted.select('creation_date',
                              'creation_hour',
                              df_uncasted.creation_timestamp.astype(TimestampType()),
                              'city_name',
                              'country_name',
                              'followers_count',
                              'friends_count',
                              'hashtag_count',
                              'media_attached',
                              'phrase_token',
                              'sentence_count',
                              'tid',
                              'time_zone',
                              'tweet',
                              'uid',
                              'word_token_set'
                             )
df_final.printSchema()
# Out:
# root
#  |-- creation_date: string (nullable = true)
#  |-- creation_hour: integer (nullable = true)
#  |-- creation_timestamp: timestamp (nullable = true)
#  |-- city_name: string (nullable = true)
#  |-- country_name: string (nullable = true)
#  |-- followers_count: integer (nullable = true)
#  |-- friends_count: integer (nullable = true)
#  |-- hashtag_count: integer (nullable = true)
#  |-- media_attached: boolean (nullable = false)
#  |-- phrase_token: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- sentence_count: integer (nullable = true)
#  |-- tid: long (nullable = false)
#  |-- time_zone: string (nullable = true)
#  |-- tweet: string (nullable = true)
#  |-- uid: long (nullable = false)
#  |-- word_token_set: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
part.write.format("org.apache.spark.sql.cassandra").\
            mode('append').options(table='b0',keyspace='twitter').save()
